# %%
# define function

from math import exp

def official_numerical_score(pred, real, B=1, s=1):
    return B * sum([exp(-((n-m)/s)**2) for n, m in zip(pred, real)]) / len(pred)

def official_categorical_score(pred, real, C=1):
    return C * sum([1 if ci == di else 0 for ci, di in zip(pred, real)]) / len(pred)

# data load
import warnings
warnings.filterwarnings('ignore')
import json
import pickle
import datetime

import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, accuracy_score

data = pd.read_csv('dataset_kor/교통사망사고정보/Kor_Train_교통사망사고정보(12.1~17.6).csv', encoding='euc-kr', engine='python')
val_data = pd.read_csv('val_refine.csv', encoding='euc-kr', engine='python')
test = pd.read_csv('test_kor.csv', encoding='euc-kr', engine='python')

train_data = data.dropna()
target_col_list = [i.strip() for i in 
                   '사상자수, 사망자수, 중상자수, 경상자수, 부상신고자수, 주야, 요일, 발생지시도, 발생지시군구, \
                   사고유형_대분류, 사고유형_중분류, 법규위반, 도로형태_대분류, 도로형태, \
                   당사자종별_1당_대분류, 당사자종별_2당_대분류'.split(',')]

# %%
def preprocessing(data):
    onehot_col = []

    for col in data.columns:
        if isinstance(data[col].values[0], str):
            onehot_col.append(col)

    data = pd.get_dummies(data, prefix=onehot_col)
    return data

class CustomRegModel:
    def __init__(self):
        self.model = RandomForestRegressor(n_estimators=20, max_depth=5, random_state=0)
    def train(self, X, y):
        self.model.fit(X, y)
    def predict(self, X):
        self.predReal = self.model.predict(X)
        self.pred = [round(x) for x in self.predReal]
        return self.pred
    def evaluation(self, test_y, pred):
        self.ev = {}
        self.ev['MSE'] = mean_squared_error(test_y, pred)
        self.ev['Official Numerical Score'] = official_numerical_score(test_y, pred)
        return self.ev

class CustomClfModel:
    def __init__(self):
        self.model = RandomForestClassifier(n_estimators=20, max_depth=5, random_state=0)
    def train(self, X, y):
        self.model.fit(X, y)
    def predict(self, X):
        self.pred = self.model.predict(X)
        return self.pred
    def evaluation(self, test_y, pred):
        self.ev = {}
        self.ev['ACC'] = accuracy_score(test_y, pred)
        self.ev['Official Categorical Score'] = official_categorical_score(test_y, pred)
        return self.ev

# %%
# 필요 모델 리스팅
model_dict = {}

for i, row in test.iterrows():
    target_col_list = []
    dependent_col_list = []
    for key, value in row.items():
        if isinstance(value, float) and np.isnan(value):
            target_col_list.append(key)
        else:
            dependent_col_list.append(key)
    
    for t_col in target_col_list:
        model_name = t_col + ':' + '/'.join(dependent_col_list)
        model_dict[model_name] = ''

save_dict = {}
loss_all_val1 = 0
if val_data is not None:
    loss_all_val2 = 0

for i, model_name in enumerate(model_dict):
    target_col, dependent_col_list_string = model_name.split(':')
    dependent_col_list = dependent_col_list_string.split('/')
    result = {
        'target_col' : target_col,
        'dependent_col' : dependent_col_list
    }
    print('tar_col : ', target_col)
    print('dep_col : ', dependent_col_list)

    data['val'] = 0

    if val_data is not None:
        val_data['val'] = 1
        data = data.append(val_data)

    X = data[dependent_col_list + ['val']]
    y = data[[target_col, 'val']]

    X = preprocessing(X)

    if val_data is not None:
        val_X = X[X['val'] == 1]
        val_y = y[y['val'] == 1]
        X = X[X['val'] == 0]
        y = y[y['val'] == 0]

        val_X = val_X.drop(['val'], axis=1)
        val_y = val_y.drop(['val'], axis=1)

    X = X.drop(['val'], axis=1)
    y = y.drop(['val'], axis=1)

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

    if isinstance(y_test[target_col].values[0], str): # clf
        model = CustomClfModel()
    else:
        model = CustomRegModel()
    model.train(X_train, y_train)
    pred = model.predict(X_test)
    val_eval = model.evaluation(pred, y_test.values)
    print('val1 : ', val_eval)
    result['val_1'] = val_eval
    loss_all_val1 = val_eval

    if val_data is not None:
        val_pred = model.predict(val_X)
        val_eval = model.evaluation(val_pred, val_y.values)
        print('val2 : ', val_eval)
        result['val_2'] = val_eval
        loss_all_val2 = val_eval

    print()
    save_dict[i] = result
    model_dict[model_name] = model

save_dict['loss_all_val1'] = loss_all_val1
save_dict['loss_all_val2'] = loss_all_val2

now_string = str(datetime.datetime.now())
with open('result/' + now_string + '.json', 'w') as f:
    json.dump(save_dict, f)
with open('result/' + now_string + '.p', 'wb') as f:
    pickle.dump(model_dict, f)
# Out:
# tar_col :  사망자수
# dep_col :  ['주야', '요일', '중상자수', '부상신고자수', '발생지시도', '발생지시군구', '사고유형_대분류', '사고유형_중분류', '법규위반', '도로형태_대분류', '도로형태', '당사자종별_1당_대분류', '당사자종별_2당_대분류']
# val1 :  {'MSE': 0.055366004962779158, 'Official Numerical Score': 0.9809006664253471}
# val2 :  {'MSE': 0.02, 'Official Numerical Score': 0.9873575888234288}
#
# tar_col :  사상자수
# dep_col :  ['주야', '요일', '중상자수', '부상신고자수', '발생지시도', '발생지시군구', '사고유형_대분류', '사고유형_중분류', '법규위반', '도로형태_대분류', '도로형태', '당사자종별_1당_대분류', '당사자종별_2당_대분류']
# val1 :  {'MSE': 2.033756580984825, 'Official Numerical Score': 0.7898950101692348}
# val2 :  {'MSE': 0.95999999999999996, 'Official Numerical Score': 0.6416282197301032}
#
# tar_col :  경상자수
# dep_col :  ['주야', '요일', '중상자수', '부상신고자수', '발생지시도', '발생지시군구', '사고유형_대분류', '사고유형_중분류', '법규위반', '도로형태_대분류', '도로형태', '당사자종별_1당_대분류', '당사자종별_2당_대분류']
# val1 :  {'MSE': 1.0777674706246134, 'Official Numerical Score': 0.8544114016268608}
# val2 :  {'MSE': 0.47999999999999998, 'Official Numerical Score': 0.7584540467304108}
#
# tar_col :  사상자수
# dep_col :  ['주야', '요일', '사망자수', '경상자수', '발생지시도', '발생지시군구', '사고유형_대분류', '사고유형_중분류', '법규위반', '도로형태_대분류', '도로형태', '당사자종별_1당_대분류', '당사자종별_2당_대분류']
# val1 :  {'MSE': 1.0791911083667798, 'Official Numerical Score': 0.8460488235664485}
# val2 :  {'MSE': 0.56000000000000005, 'Official Numerical Score': 0.833580824626452}
#
# tar_col :  중상자수
# dep_col :  ['주야', '요일', '사망자수', '경상자수', '발생지시도', '발생지시군구', '사고유형_대분류', '사고유형_중분류', '법규위반', '도로형태_대분류', '도로형태', '당사자종별_1당_대분류', '당사자종별_2당_대분류']
# val1 :  {'MSE': 0.88594327990135635, 'Official Numerical Score': 0.8676503041986843}
# val2 :  {'MSE': 0.16, 'Official Numerical Score': 0.8988607105874307}
#
# tar_col :  부상신고자수
# dep_col :  ['주야', '요일', '사망자수', '경상자수', '발생지시도', '발생지시군구', '사고유형_대분류', '사고유형_중분류', '법규위반', '도로형태_대분류', '도로형태', '당사자종별_1당_대분류', '당사자종별_2당_대분류']
# val1 :  {'MSE': 0.04401354262850108, 'Official Numerical Score': 0.9906913867916138}
# val2 :  {'MSE': 0.0, 'Official Numerical Score': 1.0}
#
# tar_col :  사상자수
# dep_col :  ['주야', '요일', '사망자수', '부상신고자수', '발생지시도', '발생지시군구', '사고유형_대분류', '사고유형_중분류', '법규위반', '도로형태_대분류', '도로형태', '당사자종별_1당_대분류', '당사자종별_2당_대분류']
# val1 :  {'MSE': 2.417639827904118, 'Official Numerical Score': 0.7077353171913265}
# val2 :  {'MSE': 1.1599999999999999, 'Official Numerical Score': 0.66557043522313}
#
# tar_col :  중상자수
# dep_col :  ['주야', '요일', '사망자수', '부상신고자수', '발생지시도', '발생지시군구', '사고유형_대분류', '사고유형_중분류', '법규위반', '도로형태_대분류', '도로형태', '당사자종별_1당_대분류', '당사자종별_2당_대분류']
# val1 :  {'MSE': 1.0007671064743786, 'Official Numerical Score': 0.7412212082873777}
# val2 :  {'MSE': 0.66000000000000003, 'Official Numerical Score': 0.706544261109389}
#
# tar_col :  경상자수
# dep_col :  ['주야', '요일', '사망자수', '부상신고자수', '발생지시도', '발생지시군구', '사고유형_대분류', '사고유형_중분류', '법규위반', '도로형태_대분류', '도로형태', '당사자종별_1당_대분류', '당사자종별_2당_대분류']
# val1 :  {'MSE': 0.97166053921568629, 'Official Numerical Score': 0.8413268385770329}
# val2 :  {'MSE': 0.41999999999999998, 'Official Numerical Score': 0.765445322776065}
#
# tar_col :  사망자수
# dep_col :  ['주야', '요일', '경상자수', '부상신고자수', '발생지시도', '발생지시군구', '사고유형_대분류', '사고유형_중분류', '법규위반', '도로형태_대분류', '도로형태', '당사자종별_1당_대분류', '당사자종별_2당_대분류']
# val1 :  {'MSE': 0.071275619455490977, 'Official Numerical Score': 0.9718888530466203}
# val2 :  {'MSE': 0.080000000000000002, 'Official Numerical Score': 0.9494303552937154}
#
# tar_col :  사상자수
# dep_col :  ['주야', '요일', '경상자수', '부상신고자수', '발생지시도', '발생지시군구', '사고유형_대분류', '사고유형_중분류', '법규위반', '도로형태_대분류', '도로형태', '당사자종별_1당_대분류', '당사자종별_2당_대분류']
# val1 :  {'MSE': 1.1942577886377519, 'Official Numerical Score': 0.8224122612343067}
# val2 :  {'MSE': 0.52000000000000002, 'Official Numerical Score': 0.7950411393453871}
#
# tar_col :  중상자수
# dep_col :  ['주야', '요일', '경상자수', '부상신고자수', '발생지시도', '발생지시군구', '사고유형_대분류', '사고유형_중분류', '법규위반', '도로형태_대분류', '도로형태', '당사자종별_1당_대분류', '당사자종별_2당_대분류']
# val1 :  {'MSE': 0.8696248856358646, 'Official Numerical Score': 0.8482246722299638}
# val2 :  {'MSE': 0.16, 'Official Numerical Score': 0.8988607105874309}
#
# tar_col :  사고유형_대분류
# dep_col :  ['주야', '요일', '사망자수', '사상자수', '중상자수', '경상자수', '부상신고자수', '발생지시도', '발생지시군구', '도로형태_대분류', '도로형태', '당사자종별_1당_대분류', '당사자종별_2당_대분류']
# val1 :  {'ACC': 0.98188185140073081, 'Official Categorical Score': 0.9818818514007308}
# val2 :  {'ACC': 1.0, 'Official Categorical Score': 1.0}
#
# tar_col :  사고유형_중분류
# dep_col :  ['주야', '요일', '사망자수', '사상자수', '중상자수', '경상자수', '부상신고자수', '발생지시도', '발생지시군구', '도로형태_대분류', '도로형태', '당사자종별_1당_대분류', '당사자종별_2당_대분류']
# val1 :  {'ACC': 0.48905442383703251, 'Official Categorical Score': 0.4890544238370325}
# val2 :  {'ACC': 0.73999999999999999, 'Official Categorical Score': 0.74}
#
# tar_col :  법규위반
# dep_col :  ['주야', '요일', '사망자수', '사상자수', '중상자수', '경상자수', '부상신고자수', '발생지시도', '발생지시군구', '도로형태_대분류', '도로형태', '당사자종별_1당_대분류', '당사자종별_2당_대분류']
# val1 :  {'ACC': 0.71129326047358832, 'Official Categorical Score': 0.7112932604735883}
# val2 :  {'ACC': 0.69999999999999996, 'Official Categorical Score': 0.7}
#
# tar_col :  도로형태_대분류
# dep_col :  ['주야', '요일', '사망자수', '사상자수', '중상자수', '경상자수', '부상신고자수', '발생지시도', '발생지시군구', '사고유형_대분류', '사고유형_중분류', '법규위반', '당사자종별_2당_대분류']
# val1 :  {'ACC': 0.73113064565019703, 'Official Categorical Score': 0.731130645650197}
# val2 :  {'ACC': 0.78000000000000003, 'Official Categorical Score': 0.78}
#
# tar_col :  도로형태
# dep_col :  ['주야', '요일', '사망자수', '사상자수', '중상자수', '경상자수', '부상신고자수', '발생지시도', '발생지시군구', '사고유형_대분류', '사고유형_중분류', '법규위반', '당사자종별_2당_대분류']
# val1 :  {'ACC': 0.65057506053268765, 'Official Categorical Score': 0.6505750605326877}
# val2 :  {'ACC': 0.71999999999999997, 'Official Categorical Score': 0.72}
#
# tar_col :  당사자종별_1당_대분류
# dep_col :  ['주야', '요일', '사망자수', '사상자수', '중상자수', '경상자수', '부상신고자수', '발생지시도', '발생지시군구', '사고유형_대분류', '사고유형_중분류', '법규위반', '당사자종별_2당_대분류']
# val1 :  {'ACC': 0.51390148080991238, 'Official Categorical Score': 0.5139014808099124}
# val2 :  {'ACC': 0.57999999999999996, 'Official Categorical Score': 0.58}
#
# tar_col :  도로형태_대분류
# dep_col :  ['주야', '요일', '사망자수', '사상자수', '중상자수', '경상자수', '부상신고자수', '발생지시도', '발생지시군구', '사고유형_대분류', '사고유형_중분류', '법규위반', '당사자종별_1당_대분류']
# val1 :  {'ACC': 0.75543150271575132, 'Official Categorical Score': 0.7554315027157513}
# val2 :  {'ACC': 0.81999999999999995, 'Official Categorical Score': 0.82}
#
# tar_col :  도로형태
# dep_col :  ['주야', '요일', '사망자수', '사상자수', '중상자수', '경상자수', '부상신고자수', '발생지시도', '발생지시군구', '사고유형_대분류', '사고유형_중분류', '법규위반', '당사자종별_1당_대분류']
# val1 :  {'ACC': 0.68815908406146431, 'Official Categorical Score': 0.6881590840614643}
# val2 :  {'ACC': 0.76000000000000001, 'Official Categorical Score': 0.76}
#
# tar_col :  당사자종별_2당_대분류
# dep_col :  ['주야', '요일', '사망자수', '사상자수', '중상자수', '경상자수', '부상신고자수', '발생지시도', '발생지시군구', '사고유형_대분류', '사고유형_중분류', '법규위반', '당사자종별_1당_대분류']
# val1 :  {'ACC': 0.76233453670276774, 'Official Categorical Score': 0.7623345367027677}
# val2 :  {'ACC': 0.81999999999999995, 'Official Categorical Score': 0.82}
#
# tar_col :  도로형태_대분류
# dep_col :  ['주야', '요일', '사망자수', '사상자수', '중상자수', '경상자수', '부상신고자수', '발생지시도', '발생지시군구', '사고유형_대분류', '사고유형_중분류', '법규위반']
# val1 :  {'ACC': 0.75788525082607394, 'Official Categorical Score': 0.7578852508260739}
# val2 :  {'ACC': 0.83999999999999997, 'Official Categorical Score': 0.84}
#
# tar_col :  도로형태
# dep_col :  ['주야', '요일', '사망자수', '사상자수', '중상자수', '경상자수', '부상신고자수', '발생지시도', '발생지시군구', '사고유형_대분류', '사고유형_중분류', '법규위반']
# val1 :  {'ACC': 0.68086382723455308, 'Official Categorical Score': 0.6808638272345531}
# val2 :  {'ACC': 0.78000000000000003, 'Official Categorical Score': 0.78}
#
# tar_col :  당사자종별_1당_대분류
# dep_col :  ['주야', '요일', '사망자수', '사상자수', '중상자수', '경상자수', '부상신고자수', '발생지시도', '발생지시군구', '사고유형_대분류', '사고유형_중분류', '법규위반']
# val1 :  {'ACC': 0.50314465408805031, 'Official Categorical Score': 0.5031446540880503}
# val2 :  {'ACC': 0.54000000000000004, 'Official Categorical Score': 0.54}
#
# tar_col :  당사자종별_2당_대분류
# dep_col :  ['주야', '요일', '사망자수', '사상자수', '중상자수', '경상자수', '부상신고자수', '발생지시도', '발생지시군구', '사고유형_대분류', '사고유형_중분류', '법규위반']
# val1 :  {'ACC': 0.73504784688995217, 'Official Categorical Score': 0.7350478468899522}
# val2 :  {'ACC': 0.80000000000000004, 'Official Categorical Score': 0.8}
#
# tar_col :  사망자수
# dep_col :  ['주야', '요일', '중상자수', '경상자수', '부상신고자수', '발생지시도', '사고유형_대분류', '사고유형_중분류', '법규위반', '도로형태_대분류', '도로형태', '당사자종별_1당_대분류', '당사자종별_2당_대분류']
# val1 :  {'MSE': 0.06300388175574799, 'Official Numerical Score': 0.9762041993755552}
# val2 :  {'MSE': 0.040000000000000001, 'Official Numerical Score': 0.9747151776468576}
#
# tar_col :  사상자수
# dep_col :  ['주야', '요일', '중상자수', '경상자수', '부상신고자수', '발생지시도', '사고유형_대분류', '사고유형_중분류', '법규위반', '도로형태_대분류', '도로형태', '당사자종별_1당_대분류', '당사자종별_2당_대분류']
# val1 :  {'MSE': 0.20363744782349433, 'Official Numerical Score': 0.9190793914538183}
# val2 :  {'MSE': 0.20000000000000001, 'Official Numerical Score': 0.8735758882342882}
#
# tar_col :  발생지시군구
# dep_col :  ['주야', '요일', '중상자수', '경상자수', '부상신고자수', '발생지시도', '사고유형_대분류', '사고유형_중분류', '법규위반', '도로형태_대분류', '도로형태', '당사자종별_1당_대분류', '당사자종별_2당_대분류']
# val1 :  {'ACC': 0.35948198868710923, 'Official Categorical Score': 0.35948198868710923}
# val2 :  {'ACC': 1.0, 'Official Categorical Score': 1.0}
#
# tar_col :  중상자수
# dep_col :  ['주야', '요일', '사망자수', '사상자수', '부상신고자수', '발생지시도', '사고유형_대분류', '사고유형_중분류', '법규위반', '도로형태_대분류', '도로형태', '당사자종별_1당_대분류', '당사자종별_2당_대분류']
# val1 :  {'MSE': 0.34586801426872771, 'Official Numerical Score': 0.9102506114488812}
# val2 :  {'MSE': 0.059999999999999998, 'Official Numerical Score': 0.9620727664702865}
#
# tar_col :  경상자수
# dep_col :  ['주야', '요일', '사망자수', '사상자수', '부상신고자수', '발생지시도', '사고유형_대분류', '사고유형_중분류', '법규위반', '도로형태_대분류', '도로형태', '당사자종별_1당_대분류', '당사자종별_2당_대분류']
# val1 :  {'MSE': 0.3509943603443158, 'Official Numerical Score': 0.8969069425861161}
# val2 :  {'MSE': 0.12, 'Official Numerical Score': 0.924145532940573}
#
# tar_col :  발생지시군구
# dep_col :  ['주야', '요일', '사망자수', '사상자수', '부상신고자수', '발생지시도', '사고유형_대분류', '사고유형_중분류', '법규위반', '도로형태_대분류', '도로형태', '당사자종별_1당_대분류', '당사자종별_2당_대분류']
# val1 :  {'ACC': 0.32394783639596919, 'Official Categorical Score': 0.3239478363959692}
# val2 :  {'ACC': 0.92000000000000004, 'Official Categorical Score': 0.92}
#
# tar_col :  발생지시도
# dep_col :  ['주야', '요일', '사망자수', '사상자수', '중상자수', '경상자수', '부상신고자수', '사고유형_대분류', '사고유형_중분류', '법규위반', '도로형태_대분류', '도로형태', '당사자종별_1당_대분류', '당사자종별_2당_대분류']
# val1 :  {'ACC': 0.30097662030186445, 'Official Categorical Score': 0.30097662030186445}
# val2 :  {'ACC': 0.64000000000000001, 'Official Categorical Score': 0.64}
#
# tar_col :  발생지시군구
# dep_col :  ['주야', '요일', '사망자수', '사상자수', '중상자수', '경상자수', '부상신고자수', '사고유형_대분류', '사고유형_중분류', '법규위반', '도로형태_대분류', '도로형태', '당사자종별_1당_대분류', '당사자종별_2당_대분류']
# val1 :  {'ACC': 0.24704491725768321, 'Official Categorical Score': 0.2470449172576832}
# val2 :  {'ACC': 0.88, 'Official Categorical Score': 0.88}
#
# tar_col :  요일
# dep_col :  ['주야', '사망자수', '사상자수', '중상자수', '경상자수', '부상신고자수', '발생지시도', '발생지시군구', '법규위반', '도로형태_대분류', '도로형태', '당사자종별_1당_대분류', '당사자종별_2당_대분류']
# val1 :  {'ACC': 0.32443198583652993, 'Official Categorical Score': 0.32443198583652993}
# val2 :  {'ACC': 0.83999999999999997, 'Official Categorical Score': 0.84}
#
# tar_col :  사고유형_대분류
# dep_col :  ['주야', '사망자수', '사상자수', '중상자수', '경상자수', '부상신고자수', '발생지시도', '발생지시군구', '법규위반', '도로형태_대분류', '도로형태', '당사자종별_1당_대분류', '당사자종별_2당_대분류']
# val1 :  {'ACC': 0.97657631113730115, 'Official Categorical Score': 0.9765763111373011}
# val2 :  {'ACC': 1.0, 'Official Categorical Score': 1.0}
#
# tar_col :  사고유형_중분류
# dep_col :  ['주야', '사망자수', '사상자수', '중상자수', '경상자수', '부상신고자수', '발생지시도', '발생지시군구', '법규위반', '도로형태_대분류', '도로형태', '당사자종별_1당_대분류', '당사자종별_2당_대분류']
# val1 :  {'ACC': 0.56281259193880551, 'Official Categorical Score': 0.5628125919388055}
# val2 :  {'ACC': 0.78000000000000003, 'Official Categorical Score': 0.78}
#
# tar_col :  요일
# dep_col :  ['주야', '사망자수', '사상자수', '중상자수', '경상자수', '부상신고자수', '발생지시도', '발생지시군구', '사고유형_대분류', '도로형태', '당사자종별_1당_대분류', '당사자종별_2당_대분류']
# val1 :  {'ACC': 0.33827849588719155, 'Official Categorical Score': 0.33827849588719155}
# val2 :  {'ACC': 0.90000000000000002, 'Official Categorical Score': 0.9}
#
# tar_col :  사고유형_중분류
# dep_col :  ['주야', '사망자수', '사상자수', '중상자수', '경상자수', '부상신고자수', '발생지시도', '발생지시군구', '사고유형_대분류', '도로형태', '당사자종별_1당_대분류', '당사자종별_2당_대분류']
# val1 :  {'ACC': 0.50762687004986795, 'Official Categorical Score': 0.507626870049868}
# val2 :  {'ACC': 0.64000000000000001, 'Official Categorical Score': 0.64}
#
# tar_col :  법규위반
# dep_col :  ['주야', '사망자수', '사상자수', '중상자수', '경상자수', '부상신고자수', '발생지시도', '발생지시군구', '사고유형_대분류', '도로형태', '당사자종별_1당_대분류', '당사자종별_2당_대분류']
# val1 :  {'ACC': 0.70035149384885764, 'Official Categorical Score': 0.7003514938488576}
# val2 :  {'ACC': 0.69999999999999996, 'Official Categorical Score': 0.7}
#
# tar_col :  도로형태_대분류
# dep_col :  ['주야', '사망자수', '사상자수', '중상자수', '경상자수', '부상신고자수', '발생지시도', '발생지시군구', '사고유형_대분류', '도로형태', '당사자종별_1당_대분류', '당사자종별_2당_대분류']
# val1 :  {'ACC': 0.95685873062298921, 'Official Categorical Score': 0.9568587306229892}
# val2 :  {'ACC': 1.0, 'Official Categorical Score': 1.0}
#
# tar_col :  주야
# dep_col :  ['요일', '중상자수', '경상자수', '부상신고자수', '발생지시도', '발생지시군구', '사고유형_대분류', '사고유형_중분류', '법규위반', '도로형태_대분류', '도로형태', '당사자종별_2당_대분류']
# val1 :  {'ACC': 0.67800817757009346, 'Official Categorical Score': 0.6780081775700935}
# val2 :  {'ACC': 0.90000000000000002, 'Official Categorical Score': 0.9}
#
# tar_col :  사망자수
# dep_col :  ['요일', '중상자수', '경상자수', '부상신고자수', '발생지시도', '발생지시군구', '사고유형_대분류', '사고유형_중분류', '법규위반', '도로형태_대분류', '도로형태', '당사자종별_2당_대분류']
# val1 :  {'MSE': 0.057013706620005836, 'Official Numerical Score': 0.9778295603852881}
# val2 :  {'MSE': 0.040000000000000001, 'Official Numerical Score': 0.9747151776468577}
#
# tar_col :  사상자수
# dep_col :  ['요일', '중상자수', '경상자수', '부상신고자수', '발생지시도', '발생지시군구', '사고유형_대분류', '사고유형_중분류', '법규위반', '도로형태_대분류', '도로형태', '당사자종별_2당_대분류']
# val1 :  {'MSE': 0.38511939429237041, 'Official Numerical Score': 0.9279820449441644}
# val2 :  {'MSE': 0.16, 'Official Numerical Score': 0.8988607105874306}
#
# tar_col :  당사자종별_1당_대분류
# dep_col :  ['요일', '중상자수', '경상자수', '부상신고자수', '발생지시도', '발생지시군구', '사고유형_대분류', '사고유형_중분류', '법규위반', '도로형태_대분류', '도로형태', '당사자종별_2당_대분류']
# val1 :  {'ACC': 0.50596103518464675, 'Official Categorical Score': 0.5059610351846467}
# val2 :  {'ACC': 0.54000000000000004, 'Official Categorical Score': 0.54}
#
# tar_col :  주야
# dep_col :  ['요일', '사망자수', '경상자수', '부상신고자수', '발생지시도', '발생지시군구', '사고유형_대분류', '사고유형_중분류', '법규위반', '도로형태_대분류', '당사자종별_1당_대분류', '당사자종별_2당_대분류']
# val1 :  {'ACC': 0.72357723577235777, 'Official Categorical Score': 0.7235772357723578}
# val2 :  {'ACC': 0.95999999999999996, 'Official Categorical Score': 0.96}
#
# tar_col :  사상자수
# dep_col :  ['요일', '사망자수', '경상자수', '부상신고자수', '발생지시도', '발생지시군구', '사고유형_대분류', '사고유형_중분류', '법규위반', '도로형태_대분류', '당사자종별_1당_대분류', '당사자종별_2당_대분류']
# val1 :  {'MSE': 0.75761090171064072, 'Official Numerical Score': 0.8430426557663927}
# val2 :  {'MSE': 0.57999999999999996, 'Official Numerical Score': 0.8209384134498808}
#
# tar_col :  중상자수
# dep_col :  ['요일', '사망자수', '경상자수', '부상신고자수', '발생지시도', '발생지시군구', '사고유형_대분류', '사고유형_중분류', '법규위반', '도로형태_대분류', '당사자종별_1당_대분류', '당사자종별_2당_대분류']
# val1 :  {'MSE': 0.85176606832657786, 'Official Numerical Score': 0.8721064466978325}
# val2 :  {'MSE': 0.12, 'Official Numerical Score': 0.924145532940573}
#
# tar_col :  도로형태
# dep_col :  ['요일', '사망자수', '경상자수', '부상신고자수', '발생지시도', '발생지시군구', '사고유형_대분류', '사고유형_중분류', '법규위반', '도로형태_대분류', '당사자종별_1당_대분류', '당사자종별_2당_대분류']
# val1 :  {'ACC': 0.75917895345475572, 'Official Categorical Score': 0.7591789534547557}
# val2 :  {'ACC': 0.85999999999999999, 'Official Categorical Score': 0.86}

# %%
save_dict
# Out:
# {0: {'dependent_col': ['주야',
#    '요일',
#    '중상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '사망자수',
#   'val_1': {'MSE': 0.061953352769679303,
#    'Official Numerical Score': 0.9780375489674865},
#   'val_2': {'MSE': 0.040000000000000001,
#    'Official Numerical Score': 0.9747151776468577}},
#  1: {'dependent_col': ['주야',
#    '요일',
#    '중상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '사상자수',
#   'val_1': {'MSE': 2.3761367770098216,
#    'Official Numerical Score': 0.8204424092030121},
#   'val_2': {'MSE': 1.74, 'Official Numerical Score': 0.6269130443342269}},
#  2: {'dependent_col': ['주야',
#    '요일',
#    '중상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '경상자수',
#   'val_1': {'MSE': 1.0639070442992011,
#    'Official Numerical Score': 0.8647965236630262},
#   'val_2': {'MSE': 0.62, 'Official Numerical Score': 0.7318290834625314}},
#  3: {'dependent_col': ['주야',
#    '요일',
#    '사망자수',
#    '경상자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '사상자수',
#   'val_1': {'MSE': 0.89416455237404857,
#    'Official Numerical Score': 0.81272771766798},
#   'val_2': {'MSE': 0.44, 'Official Numerical Score': 0.7837388690835533}},
#  4: {'dependent_col': ['주야',
#    '요일',
#    '사망자수',
#    '경상자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '중상자수',
#   'val_1': {'MSE': 1.1591895803183792,
#    'Official Numerical Score': 0.8493996775831528},
#   'val_2': {'MSE': 0.28000000000000003,
#    'Official Numerical Score': 0.8539422010120632}},
#  5: {'dependent_col': ['주야',
#    '요일',
#    '사망자수',
#    '경상자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '부상신고자수',
#   'val_1': {'MSE': 0.043517515348501262,
#    'Official Numerical Score': 0.9883939677522317},
#   'val_2': {'MSE': 0.0, 'Official Numerical Score': 1.0}},
#  6: {'dependent_col': ['주야',
#    '요일',
#    '사망자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '사상자수',
#   'val_1': {'MSE': 3.437094448449892,
#    'Official Numerical Score': 0.7107445768166311},
#   'val_2': {'MSE': 4.7599999999999998,
#    'Official Numerical Score': 0.5722003371341543}},
#  7: {'dependent_col': ['주야',
#    '요일',
#    '사망자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '중상자수',
#   'val_1': {'MSE': 0.81198272759985601,
#    'Official Numerical Score': 0.8168611480913222},
#   'val_2': {'MSE': 0.68000000000000005,
#    'Official Numerical Score': 0.6939018499328179}},
#  8: {'dependent_col': ['주야',
#    '요일',
#    '사망자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '경상자수',
#   'val_1': {'MSE': 0.9570761494252874,
#    'Official Numerical Score': 0.8468435542972269},
#   'val_2': {'MSE': 0.71999999999999997,
#    'Official Numerical Score': 0.7304889425477942}},
#  9: {'dependent_col': ['주야',
#    '요일',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '사망자수',
#   'val_1': {'MSE': 0.059698816780207963,
#    'Official Numerical Score': 0.9782763788097898},
#   'val_2': {'MSE': 0.040000000000000001,
#    'Official Numerical Score': 0.9747151776468577}},
#  10: {'dependent_col': ['주야',
#    '요일',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '사상자수',
#   'val_1': {'MSE': 1.1089835361488904,
#    'Official Numerical Score': 0.8151178272920978},
#   'val_2': {'MSE': 0.57999999999999996,
#    'Official Numerical Score': 0.7261779483316144}},
#  11: {'dependent_col': ['주야',
#    '요일',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '중상자수',
#   'val_1': {'MSE': 0.73008217220435867,
#    'Official Numerical Score': 0.8335292639737033},
#   'val_2': {'MSE': 0.32000000000000001,
#    'Official Numerical Score': 0.8286573786589208}},
#  12: {'dependent_col': ['주야',
#    '요일',
#    '사망자수',
#    '사상자수',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '사고유형_대분류',
#   'val_1': {'ACC': 0.97467902995720401,
#    'Official Categorical Score': 0.974679029957204},
#   'val_2': {'ACC': 1.0, 'Official Categorical Score': 1.0}},
#  13: {'dependent_col': ['주야',
#    '요일',
#    '사망자수',
#    '사상자수',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '사고유형_중분류',
#   'val_1': {'ACC': 0.46404414382342468,
#    'Official Categorical Score': 0.4640441438234247},
#   'val_2': {'ACC': 0.47999999999999998, 'Official Categorical Score': 0.48}},
#  14: {'dependent_col': ['주야',
#    '요일',
#    '사망자수',
#    '사상자수',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '법규위반',
#   'val_1': {'ACC': 0.70451314854299929,
#    'Official Categorical Score': 0.7045131485429993},
#   'val_2': {'ACC': 0.69999999999999996, 'Official Categorical Score': 0.7}},
#  15: {'dependent_col': ['주야',
#    '요일',
#    '사망자수',
#    '사상자수',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '당사자종별_2당_대분류'],
#   'target_col': '도로형태_대분류',
#   'val_1': {'ACC': 0.7323518978361121,
#    'Official Categorical Score': 0.7323518978361121},
#   'val_2': {'ACC': 0.78000000000000003, 'Official Categorical Score': 0.78}},
#  16: {'dependent_col': ['주야',
#    '요일',
#    '사망자수',
#    '사상자수',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '당사자종별_2당_대분류'],
#   'target_col': '도로형태',
#   'val_1': {'ACC': 0.63473796033994334,
#    'Official Categorical Score': 0.6347379603399433},
#   'val_2': {'ACC': 0.69999999999999996, 'Official Categorical Score': 0.7}},
#  17: {'dependent_col': ['주야',
#    '요일',
#    '사망자수',
#    '사상자수',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '당사자종별_2당_대분류'],
#   'target_col': '당사자종별_1당_대분류',
#   'val_1': {'ACC': 0.49664192294096854,
#    'Official Categorical Score': 0.49664192294096854},
#   'val_2': {'ACC': 0.54000000000000004, 'Official Categorical Score': 0.54}},
#  18: {'dependent_col': ['주야',
#    '요일',
#    '사망자수',
#    '사상자수',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '당사자종별_1당_대분류'],
#   'target_col': '도로형태_대분류',
#   'val_1': {'ACC': 0.73694424841213835,
#    'Official Categorical Score': 0.7369442484121383},
#   'val_2': {'ACC': 0.76000000000000001, 'Official Categorical Score': 0.76}},
#  19: {'dependent_col': ['주야',
#    '요일',
#    '사망자수',
#    '사상자수',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '당사자종별_1당_대분류'],
#   'target_col': '도로형태',
#   'val_1': {'ACC': 0.66537513208876364,
#    'Official Categorical Score': 0.6653751320887636},
#   'val_2': {'ACC': 0.73999999999999999, 'Official Categorical Score': 0.74}},
#  20: {'dependent_col': ['주야',
#    '요일',
#    '사망자수',
#    '사상자수',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '당사자종별_1당_대분류'],
#   'target_col': '당사자종별_2당_대분류',
#   'val_1': {'ACC': 0.74068213783403658,
#    'Official Categorical Score': 0.7406821378340366},
#   'val_2': {'ACC': 0.78000000000000003, 'Official Categorical Score': 0.78}},
#  21: {'dependent_col': ['주야',
#    '요일',
#    '사망자수',
#    '사상자수',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반'],
#   'target_col': '도로형태_대분류',
#   'val_1': {'ACC': 0.73043173043173049,
#    'Official Categorical Score': 0.7304317304317305},
#   'val_2': {'ACC': 0.78000000000000003, 'Official Categorical Score': 0.78}},
#  22: {'dependent_col': ['주야',
#    '요일',
#    '사망자수',
#    '사상자수',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반'],
#   'target_col': '도로형태',
#   'val_1': {'ACC': 0.65504555010511567,
#    'Official Categorical Score': 0.6550455501051157},
#   'val_2': {'ACC': 0.73999999999999999, 'Official Categorical Score': 0.74}},
#  23: {'dependent_col': ['주야',
#    '요일',
#    '사망자수',
#    '사상자수',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반'],
#   'target_col': '당사자종별_1당_대분류',
#   'val_1': {'ACC': 0.49772647778943685,
#    'Official Categorical Score': 0.49772647778943685},
#   'val_2': {'ACC': 0.54000000000000004, 'Official Categorical Score': 0.54}},
#  24: {'dependent_col': ['주야',
#    '요일',
#    '사망자수',
#    '사상자수',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반'],
#   'target_col': '당사자종별_2당_대분류',
#   'val_1': {'ACC': 0.72468575418994419,
#    'Official Categorical Score': 0.7246857541899442},
#   'val_2': {'ACC': 0.73999999999999999, 'Official Categorical Score': 0.74}},
#  25: {'dependent_col': ['주야',
#    '요일',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '사망자수',
#   'val_1': {'MSE': 0.069884977344022312,
#    'Official Numerical Score': 0.9745910703719486},
#   'val_2': {'MSE': 0.080000000000000002,
#    'Official Numerical Score': 0.9494303552937153}},
#  26: {'dependent_col': ['주야',
#    '요일',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '사상자수',
#   'val_1': {'MSE': 0.20354906054279751,
#    'Official Numerical Score': 0.9344389667952974},
#   'val_2': {'MSE': 0.20000000000000001,
#    'Official Numerical Score': 0.8735758882342882}},
#  27: {'dependent_col': ['주야',
#    '요일',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '발생지시군구',
#   'val_1': {'ACC': 0.24348732198680098,
#    'Official Categorical Score': 0.24348732198680098},
#   'val_2': {'ACC': 0.90000000000000002, 'Official Categorical Score': 0.9}},
#  28: {'dependent_col': ['주야',
#    '요일',
#    '사망자수',
#    '사상자수',
#    '부상신고자수',
#    '발생지시도',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '중상자수',
#   'val_1': {'MSE': 0.31293342579750349,
#    'Official Numerical Score': 0.8976631807259995},
#   'val_2': {'MSE': 0.23999999999999999,
#    'Official Numerical Score': 0.8482910658811461}},
#  29: {'dependent_col': ['주야',
#    '요일',
#    '사망자수',
#    '사상자수',
#    '부상신고자수',
#    '발생지시도',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '경상자수',
#   'val_1': {'MSE': 0.32571824160609208,
#    'Official Numerical Score': 0.8941656786688873},
#   'val_2': {'MSE': 0.32000000000000001,
#    'Official Numerical Score': 0.8286573786589209}},
#  30: {'dependent_col': ['주야',
#    '요일',
#    '사망자수',
#    '사상자수',
#    '부상신고자수',
#    '발생지시도',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '발생지시군구',
#   'val_1': {'ACC': 0.25017277125086385,
#    'Official Categorical Score': 0.25017277125086385},
#   'val_2': {'ACC': 0.93999999999999995, 'Official Categorical Score': 0.94}},
#  31: {'dependent_col': ['주야',
#    '요일',
#    '사망자수',
#    '사상자수',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '발생지시도',
#   'val_1': {'ACC': 0.23577095550189719,
#    'Official Categorical Score': 0.2357709555018972},
#   'val_2': {'ACC': 0.54000000000000004, 'Official Categorical Score': 0.54}},
#  32: {'dependent_col': ['주야',
#    '요일',
#    '사망자수',
#    '사상자수',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '발생지시군구',
#   'val_1': {'ACC': 0.11983471074380166,
#    'Official Categorical Score': 0.11983471074380166},
#   'val_2': {'ACC': 0.81999999999999995, 'Official Categorical Score': 0.82}},
#  33: {'dependent_col': ['주야',
#    '사망자수',
#    '사상자수',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '법규위반',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '요일',
#   'val_1': {'ACC': 0.249570299071846,
#    'Official Categorical Score': 0.249570299071846},
#   'val_2': {'ACC': 0.88, 'Official Categorical Score': 0.88}},
#  34: {'dependent_col': ['주야',
#    '사망자수',
#    '사상자수',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '법규위반',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '사고유형_대분류',
#   'val_1': {'ACC': 0.94783802333562117,
#    'Official Categorical Score': 0.9478380233356212},
#   'val_2': {'ACC': 1.0, 'Official Categorical Score': 1.0}},
#  35: {'dependent_col': ['주야',
#    '사망자수',
#    '사상자수',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '법규위반',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '사고유형_중분류',
#   'val_1': {'ACC': 0.48406988694758479,
#    'Official Categorical Score': 0.4840698869475848},
#   'val_2': {'ACC': 0.68000000000000005, 'Official Categorical Score': 0.68}},
#  36: {'dependent_col': ['주야',
#    '사망자수',
#    '사상자수',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '요일',
#   'val_1': {'ACC': 0.2441860465116279,
#    'Official Categorical Score': 0.2441860465116279},
#   'val_2': {'ACC': 0.85999999999999999, 'Official Categorical Score': 0.86}},
#  37: {'dependent_col': ['주야',
#    '사망자수',
#    '사상자수',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '사고유형_중분류',
#   'val_1': {'ACC': 0.48156367360874019,
#    'Official Categorical Score': 0.4815636736087402},
#   'val_2': {'ACC': 0.52000000000000002, 'Official Categorical Score': 0.52}},
#  38: {'dependent_col': ['주야',
#    '사망자수',
#    '사상자수',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '법규위반',
#   'val_1': {'ACC': 0.70483980913428768,
#    'Official Categorical Score': 0.7048398091342877},
#   'val_2': {'ACC': 0.69999999999999996, 'Official Categorical Score': 0.7}},
#  39: {'dependent_col': ['주야',
#    '사망자수',
#    '사상자수',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '도로형태_대분류',
#   'val_1': {'ACC': 0.95661789724396051,
#    'Official Categorical Score': 0.9566178972439605},
#   'val_2': {'ACC': 0.95999999999999996, 'Official Categorical Score': 0.96}},
#  40: {'dependent_col': ['요일',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_2당_대분류'],
#   'target_col': '주야',
#   'val_1': {'ACC': 0.63926630434782605,
#    'Official Categorical Score': 0.639266304347826},
#   'val_2': {'ACC': 0.83999999999999997, 'Official Categorical Score': 0.84}},
#  41: {'dependent_col': ['요일',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_2당_대분류'],
#   'target_col': '사망자수',
#   'val_1': {'MSE': 0.061715835876568328,
#    'Official Numerical Score': 0.9770286280654047},
#   'val_2': {'MSE': 0.02, 'Official Numerical Score': 0.9873575888234288}},
#  42: {'dependent_col': ['요일',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_2당_대분류'],
#   'target_col': '사상자수',
#   'val_1': {'MSE': 0.21462423832092078,
#    'Official Numerical Score': 0.9365843390481127},
#   'val_2': {'MSE': 0.20000000000000001,
#    'Official Numerical Score': 0.8735758882342882}},
#  43: {'dependent_col': ['요일',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_2당_대분류'],
#   'target_col': '당사자종별_1당_대분류',
#   'val_1': {'ACC': 0.5133491044271713,
#    'Official Categorical Score': 0.5133491044271713},
#   'val_2': {'ACC': 0.59999999999999998, 'Official Categorical Score': 0.6}},
#  44: {'dependent_col': ['요일',
#    '사망자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '도로형태_대분류',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '주야',
#   'val_1': {'ACC': 0.66514844804318485,
#    'Official Categorical Score': 0.6651484480431848},
#   'val_2': {'ACC': 0.92000000000000004, 'Official Categorical Score': 0.92}},
#  45: {'dependent_col': ['요일',
#    '사망자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '도로형태_대분류',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '사상자수',
#   'val_1': {'MSE': 0.80751094644661503,
#    'Official Numerical Score': 0.8456334709123401},
#   'val_2': {'MSE': 0.35999999999999999,
#    'Official Numerical Score': 0.8343085137898378}},
#  46: {'dependent_col': ['요일',
#    '사망자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '도로형태_대분류',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '중상자수',
#   'val_1': {'MSE': 0.77622730329522527,
#    'Official Numerical Score': 0.8503933469627876},
#   'val_2': {'MSE': 0.20000000000000001,
#    'Official Numerical Score': 0.8735758882342884}},
#  47: {'dependent_col': ['요일',
#    '사망자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '도로형태_대분류',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '도로형태',
#   'val_1': {'ACC': 0.73816717019133937,
#    'Official Categorical Score': 0.7381671701913394},
#   'val_2': {'ACC': 0.83999999999999997, 'Official Categorical Score': 0.84}}}

# %%
with open('result/' + now_string + '.json', 'r') as f:
    json_ = json.load(f)
    
with open('result/' + now_string + '.p', 'rb') as f:
    model_ = pickle.load(f)
