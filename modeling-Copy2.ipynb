# %%
# data load
import warnings
warnings.filterwarnings('ignore')
import json
import pickle
import datetime

import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, accuracy_score

RANDOM_SEED = 2018
n_core = 4

ori_data = pd.read_csv('dataset_kor/교통사망사고정보/Kor_Train_교통사망사고정보(12.1~17.6).csv', encoding='euc-kr', engine='python')
val_data = pd.read_csv('val_refine.csv', encoding='euc-kr', engine='python')
test_data = pd.read_csv('test_kor.csv', encoding='euc-kr', engine='python')

train_data = ori_data.dropna()
target_col_list = [i.strip() for i in 
                   '사상자수, 사망자수, 중상자수, 경상자수, 부상신고자수, 주야, 요일, 발생지시도, 발생지시군구, \
                   사고유형_대분류, 사고유형_중분류, 법규위반, 도로형태_대분류, 도로형태, \
                   당사자종별_1당_대분류, 당사자종별_2당_대분류'.split(',')]

# %%
# local function

from math import exp

def official_numerical_score(pred, real, B=1, s=1):
    return B * sum([exp(-((n-m)/s)**2) for n, m in zip(pred, real)])

def official_categorical_score(pred, real, C=1):
    return C * sum([1 if ci == di else 0 for ci, di in zip(pred, real)])

def refine_val(df, target_col, dependent_col_list):
    for t_col in target_col_list:
        df = df[[isinstance(x, float) and np.isnan(x) for x in df[t_col]]]
    for d_col in dependent_col_list:
        df = df[[not (isinstance(x, float) and np.isnan(x)) for x in df[d_col]]]
    return df

# %%
# templete function
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer
from sklearn.model_selection import ParameterGrid

def preprocessing(data):
    onehot_col = []

    for col in data.columns:
        if isinstance(data[col].values[0], str):
            onehot_col.append(col)

    data = pd.get_dummies(data, prefix=onehot_col)
    return data

class CustomHyperParameterTuner:
    def __init__(self, model, params, eval_fun, greater_is_better=True, cv=5):
        self.model = model
        self.params = params
        self.eval_fun = eval_fun
        self.greater_is_better = greater_is_better
        self.cv = cv
        self._best_model = None
        self.best_params_ = None
        self.best_score_ = None

    def fit(self, X, y, val_X=None, val_y=None):
        if val_X is None or val_y is None:
            self.model = GridSearchCV(self.model, self.params, cv=self.cv,
                                      scoring=make_scorer(self.eval_fun,
                                                          greater_is_better=self.greater_is_better,
                                                          needs_proba=False))
            self.model.fit(X, y)
            
        else:
            for param in ParameterGrid(self.params):
                self.model.set_params(**param)
                self.model.fit(X, y)
                val_pred = self.model.predict(val_X)
                score = self.eval_fun(val_pred, val_y)
                print(param, score)
                if self.best_params_ is None or ((self.best_score_ <= score) == self.greater_is_better):
                    self._best_model = self.model
                    self.best_params_ = param
                    self.best_score_ = score
            
            self.model = self._best_model
    
    def predict(self, X):
        return self.model.predict(X)
    
    def evaluation(self, test_y, pred):
        return self.model.evaluation(test_y, pred)

class CustomRegModel:
    def __init__(self):
        self.model = RandomForestRegressor(n_estimators=20, max_depth=5, random_state=RANDOM_SEED, n_jobs=n_core)
    def train(self, X, y, params=None, val_X=None, val_y=None, param_types={}, category_params_dic={}):
        if params is not None:
            self.model = CustomHyperParameterTuner(self.model, params, 
                                                   official_numerical_score, 
                                                   greater_is_better=True, cv=5,
                                                   param_types=param_types, category_params_dic=category_params_dic)
        self.model.fit(X, y, val_X, val_y)
    def predict(self, X):
        self.predReal = self.model.predict(X)
        self.pred = [round(x) for x in self.predReal]
        return self.pred
    def evaluation(self, test_y, pred):
        self.ev = {}
        self.ev['MSE'] = mean_squared_error(test_y, pred)
        self.ev['Official Numerical Score'] = official_numerical_score(test_y, pred)
        return self.ev
    def set_params(self, param):
        self.model.set_params(param)

class CustomClfModel:
    def __init__(self):
        self.model = RandomForestClassifier(n_estimators=20, max_depth=5, random_state=RANDOM_SEED, n_jobs=n_core)
    def train(self, X, y, params=None, val_X=None, val_y=None, param_types={}, category_params_dic={}):
        if params is not None:
            self.model = CustomHyperParameterTuner(self.model, params, 
                                                   official_categorical_score, 
                                                   greater_is_better=True, cv=5,
                                                   param_types=param_types, category_params_dic=category_params_dic)
        self.model.fit(X, y, val_X, val_y)
    def predict(self, X):
        self.pred = self.model.predict(X)
        return self.pred
    def evaluation(self, test_y, pred):
        self.ev = {}
        self.ev['ACC'] = accuracy_score(test_y, pred)
        self.ev['Official Categorical Score'] = official_categorical_score(test_y, pred)
        return self.ev
    def set_params(self, param):
        self.model.set_params(param)

# %%
from queue import Queue
import random

class CustomHyperParameterTuner:
    def __init__(self, model, init_params, eval_fun, greater_is_better=True, cv=5, param_types={}, category_params_dic={}):
        self.model = model
        self.init_params = init_params
        self.eval_fun = eval_fun
        self.greater_is_better = greater_is_better
        self.cv = cv
        self._best_model = None
        self.best_params_ = None
        self.best_score_ = None
        self.exploration_rank = 1.1
        self.exploitation_rank = 3
        self.exploration_ratio = 0.9
        self.exploration_decay_ratio = 0.99
        self.random_rank = False
        self.max_step = 300
        self.param_types = param_types
        self.category_params_dic = category_params_dic
        
        self.step_history = set()

    def fit(self, X, y, val_X=None, val_y=None):
        if val_X is None or val_y is None:
            self.model = GridSearchCV(self.model, self.params, cv=self.cv,
                                      scoring=make_scorer(self.eval_fun,
                                                          greater_is_better=self.greater_is_better,
                                                          needs_proba=False))
            self.model.fit(X, y)
            
        else:
            param_queue = Queue()
            for param in ParameterGrid(self.init_params):
                param_queue.put(param)
            
            n_step = 0
            while((not param_queue.empty()) and n_step < self.max_step):
                param = param_queue.get()
                n_step += 1

                self.model.set_params(**param)
                try:
                    self.model.fit(X, y)
                except ValueError:
                    continue
                    
                val_pred = self.model.predict(val_X)
                score = self.eval_fun(val_pred, val_y)
                print(param, score)
                if self.best_params_ is None or ((self.best_score_ < score) == self.greater_is_better):
                    self._best_model = self.model
                    self.best_params_ = param
                    self.best_score_ = score
                    
                    for k in param:
                        new_param1 = param.copy()
                        new_param2 = param.copy()
                        
                        if self.param_types[k] == 'uint':
                            new_param1[k] = round(param[k] * self.exploration_rank)
                            if new_param1[k] == param[k]:
                                new_param1[k] += 1
                            new_param2[k] = round(param[k] / self.exploration_rank)
                            if new_param2[k] == param[k]:
                                new_param2[k] -= 1
                        elif self.param_types[k] == 'float':
                            new_param1[k] = round(param[k] * self.exploration_rank)
                            new_param2[k] = round(param[k] / self.exploration_rank)
                        elif self.param_types[k] == 'category':
                            tmp_category = self.category_params_dic[k].copy()
                            tmp_category.remove(param[k])
                            new_param1[k] = random.choice(tmp_category)

                        key1 = '/'.join([str(ob) for ob in new_param1.values()])
                        key2 = '/'.join([str(ob) for ob in new_param2.values()])
                            
                        if key1 not in self.step_history:
                            param_queue.put(new_param1)
                            self.step_history.add(key1)
                        if key2 not in self.step_history:
                            param_queue.put(new_param2)
                            self.step_history.add(key2)

                        if random.random() < self.exploration_ratio:
                            new_param1 = param.copy()
                            new_param2 = param.copy()
                            
                            if self.param_types[k] == 'uint':
                                new_param1[k] = round(param[k] * self.exploitation_rank)
                                if new_param1[k] == param[k]:
                                    new_param1[k] += 1
                                new_param2[k] = round(param[k] / self.exploitation_rank)
                                if new_param2[k] == param[k]:
                                    new_param2[k] -= 1
                            elif self.param_types[k] == 'float':
                                new_param1[k] = round(param[k] * self.exploitation_rank)
                                new_param2[k] = round(param[k] / self.exploitation_rank)
                        
                            key1 = '/'.join([str(ob) for ob in new_param1.values()])
                            key2 = '/'.join([str(ob) for ob in new_param2.values()])
                            
                            if key1 not in self.step_history:
                                param_queue.put(new_param1)
                                self.step_history.add(key1)
                            if key2 not in self.step_history:
                                param_queue.put(new_param2)
                                self.step_history.add(key2)
                
                self.exploration_ratio *= self.exploration_decay_ratio    
            
            self.model = self._best_model
    
    def predict(self, X):
        return self.model.predict(X)
    
    def evaluation(self, test_y, pred):
        return self.model.evaluation(test_y, pred)

# %%
def rule_based_model(df):
    df['요일'] = df['요일'].fillna('금')
    return df

# %%
test_data
# Out:
#      주야   요일  사망자수  사상자수  중상자수  경상자수  부상신고자수 발생지시도 발생지시군구 사고유형_대분류 사고유형_중분류  \
# 0    야간    금   NaN   NaN   0.0   NaN     0.0    경기    화성시      차대차     측면충돌
# 1    야간    금   NaN   NaN   0.0   NaN     0.0    전남    영암군     차대사람    차도통행중
# 2    야간    월   1.0   NaN   NaN   0.0     NaN    전남    곡성군     차량단독     전도전복
# 3    야간    일   2.0   NaN   NaN   1.0     NaN    대구    달성군      차대차     측면충돌
# 4    주간    목   1.0   NaN   NaN   NaN     0.0    전남    고흥군      차대차     정면충돌
# 5    주간    목   2.0   NaN   NaN   NaN     0.0    경북    영천시      차대차       추돌
# 6    야간    수   1.0   NaN   NaN   NaN     0.0    충남    아산시      차대차       추돌
# 7    주간    월   NaN   NaN   NaN   5.0     0.0    충남    서천군      차대차       추돌
# 8    주간    일   NaN   NaN   NaN  21.0     4.0    강원    평창군      차대차     측면충돌
# 9    주간    수   NaN   NaN   NaN   0.0     0.0    충북    음성군     차대사람      횡단중
# 10   주간    수   1.0   2.0   1.0   0.0     0.0    경남    의령군      NaN      NaN
# 11   야간    화   2.0   3.0   1.0   0.0     0.0    대전     중구      NaN      NaN
# 12   야간    화   1.0   1.0   0.0   0.0     0.0    대구     북구      NaN      NaN
# 13   야간    화   1.0   1.0   0.0   0.0     0.0    울산    울주군      NaN      NaN
# 14   주간    화   1.0   5.0   1.0   3.0     0.0    경기    수원시      NaN      NaN
# 15   주간    화   1.0   1.0   0.0   0.0     0.0    전북    완주군      NaN      NaN
# 16   주간    화   1.0   6.0   3.0   2.0     0.0    경남    거창군      NaN      NaN
# 17   야간    화   1.0   1.0   0.0   0.0     0.0    충남    천안시      NaN      NaN
# 18   주간    화   1.0  11.0   2.0   8.0     0.0    충남    서산시      NaN      NaN
# 19   주간    화   1.0   1.0   0.0   0.0     0.0    전남    곡성군      NaN      NaN
# 20   야간    토   1.0  11.0   0.0   0.0    10.0    경기    의왕시      차대차       추돌
# 21   주간    화   1.0  13.0   3.0   9.0     0.0    경기    평택시      차대차       추돌
# 22   주간    화   1.0   1.0   0.0   0.0     0.0    전남    광양시     차대사람    보도통행중
# 23   야간    목   1.0   2.0   0.0   1.0     0.0    경기    평택시      차대차     측면충돌
# 24   야간    목   1.0   2.0   0.0   1.0     0.0    충남    당진시     차량단독    공작물충돌
# 25   야간    월   1.0   1.0   0.0   0.0     0.0    전북    익산시     차대사람       기타
# 26   야간    월   1.0   2.0   0.0   1.0     0.0    경남    하동군      차대차       추돌
# 27   야간    월   1.0   2.0   1.0   0.0     0.0    서울   동대문구      차대차     측면충돌
# 28   야간    수   1.0   1.0   0.0   0.0     0.0    경기    평택시     차량단독       기타
# 29   주간    수   2.0   5.0   1.0   2.0     0.0    충남    홍성군      차대차       추돌
# 30   주간    수   NaN   NaN   0.0   0.0     0.0    인천    NaN      차대차     측면충돌
# 31   야간    월   NaN   NaN   1.0   2.0     0.0    전북    NaN      차대차       기타
# 32   야간    일   1.0   2.0   NaN   NaN     0.0    대구    NaN      차대차     측면충돌
# 33   주간    일   1.0   6.0   NaN   NaN     0.0    광주    NaN      차대차       추돌
# 34   주간    수   1.0   4.0   NaN   NaN     0.0    서울    NaN      차대차       추돌
# 35   야간    수   1.0   4.0   3.0   0.0     0.0   NaN    NaN      차대차     정면충돌
# 36   주간    월   2.0   2.0   0.0   0.0     0.0   NaN    NaN     차량단독    공작물충돌
# 37   주간    월   1.0   1.0   0.0   0.0     0.0   NaN    NaN     차대사람       기타
# 38   주간    월   1.0  19.0   9.0   9.0     0.0   NaN    NaN      차대차       추돌
# 39   야간    월   1.0   1.0   0.0   0.0     0.0   NaN    NaN     차대사람       기타
# 40   주간  NaN   1.0   1.0   0.0   0.0     0.0    서울    동작구      NaN      NaN
# 41   주간  NaN   1.0   4.0   3.0   0.0     0.0    경기    가평군      NaN      NaN
# 42   주간  NaN   1.0   1.0   0.0   0.0     0.0    경기    부천시      차대차      NaN
# 43   주간  NaN   1.0   1.0   0.0   0.0     0.0    대전     동구     차량단독      NaN
# 44   야간  NaN   2.0   2.0   0.0   0.0     0.0    충남    보령시     차대사람      NaN
# 45  NaN    일   NaN   NaN   0.0   0.0     0.0    전북    고창군     차대사람       기타
# 46  NaN    일   NaN   NaN   1.0   1.0     0.0    서울    은평구      차대차       기타
# 47  NaN    목   1.0   NaN   NaN   0.0     0.0    서울    성동구      차대차     측면충돌
# 48  NaN    일   2.0   NaN   NaN   9.0     1.0    서울    서초구      차대차       추돌
# 49  NaN    화   1.0   NaN   NaN   0.0     0.0    경북    의성군      차대차     측면충돌
#
#            법규위반 도로형태_대분류      도로형태 당사자종별_1당_대분류 당사자종별_2당_대분류
# 0        중앙선 침범      단일로     기타단일로          승용차          승합차
# 1            과속      단일로     기타단일로          승용차          보행자
# 2   안전운전 의무 불이행      단일로     기타단일로          자전거           없음
# 3        중앙선 침범      단일로     기타단일로          승용차          승합차
# 4        중앙선 침범      단일로     기타단일로          화물차          화물차
# 5   안전운전 의무 불이행      단일로     기타단일로          화물차          화물차
# 6      안전거리 미확보      단일로     기타단일로          승합차          화물차
# 7   안전운전 의무 불이행      단일로     기타단일로          승용차          특수차
# 8   기타(운전자법규위반)      단일로     기타단일로         건설기계          승합차
# 9            과속      교차로      교차로내          승용차          보행자
# 10          NaN      교차로      교차로내          이륜차          화물차
# 11          NaN      단일로     기타단일로     원동기장치자전거           없음
# 12          NaN      단일로     기타단일로          승용차          화물차
# 13          NaN      단일로     기타단일로          승용차          보행자
# 14          NaN      단일로       교량위          화물차          승용차
# 15          NaN      교차로  교차로횡단보도내          승합차          보행자
# 16          NaN      교차로      교차로내          승용차          승합차
# 17          NaN      단일로     기타단일로          승용차          보행자
# 18          NaN      단일로     기타단일로          화물차          승용차
# 19          NaN      교차로      교차로내          승합차          보행자
# 20  안전운전 의무 불이행      NaN       NaN          NaN          화물차
# 21  안전운전 의무 불이행      NaN       NaN          NaN          화물차
# 22  안전운전 의무 불이행      NaN       NaN          NaN          보행자
# 23         신호위반      NaN       NaN          승용차          NaN
# 24  안전운전 의무 불이행      NaN       NaN          이륜차          NaN
# 25  보행자 보호의무 위반      NaN       NaN          승용차          NaN
# 26           과속      NaN       NaN          NaN          NaN
# 27  안전운전 의무 불이행      NaN       NaN          NaN          NaN
# 28  안전운전 의무 불이행      NaN       NaN          NaN          NaN
# 29  안전운전 의무 불이행      NaN       NaN          NaN          NaN
# 30       중앙선 침범      단일로     기타단일로          자전거          화물차
# 31  안전운전 의무 불이행      단일로     기타단일로          승용차          화물차
# 32  안전운전 의무 불이행      단일로     기타단일로          승용차          승용차
# 33  안전운전 의무 불이행      교차로     교차로부근          승용차          승용차
# 34  안전운전 의무 불이행      단일로     기타단일로          화물차          화물차
# 35       중앙선 침범      단일로     기타단일로          승용차          화물차
# 36  안전운전 의무 불이행      단일로     기타단일로          승용차           없음
# 37  안전운전 의무 불이행      교차로     교차로부근          승합차          보행자
# 38  안전운전 의무 불이행      단일로     기타단일로          승합차          승용차
# 39  안전운전 의무 불이행      교차로      교차로내          승용차          보행자
# 40         신호위반      교차로      교차로내          화물차     원동기장치자전거
# 41  안전운전 의무 불이행      단일로     기타단일로          승합차          승용차
# 42          NaN      NaN      교차로내          승합차          이륜차
# 43          NaN      NaN     기타단일로          특수차           없음
# 44          NaN      NaN     기타단일로          승용차          보행자
# 45       부당한 회전      교차로      교차로내          NaN          보행자
# 46         신호위반      교차로      교차로내          NaN          승용차
# 47  안전운전 의무 불이행      교차로       NaN          자전거          승용차
# 48  안전운전 의무 불이행      단일로       NaN          승합차          승용차
# 49  안전운전 의무 불이행      교차로       NaN          승용차     원동기장치자전거

# %%
model_meta_dict = {}
col_record = {}

for _, row in test_data.iterrows():
    target_col_list = []
    dependent_col_list = []
    for key, value in row.items():
        if isinstance(value, float) and np.isnan(value):
            target_col_list.append(key)
        else:
            dependent_col_list.append(key)
    
    for t_col in target_col_list:
        col_key = t_col + ':' + '/'.join(dependent_col_list)
        if col_record.get(col_key):
            continue
        model_dict = {}
        model_dict['target_col'] = t_col
        model_dict['dependent_col_list'] = dependent_col_list

        if val_data is not None:
            tmp_test_data = test_data.copy()
            tmp_test_data = refine_val(tmp_test_data, target_col_list, dependent_col_list)
            model_dict['val_data_loc'] = tmp_test_data.index
    
        model_meta_dict[col_key] = model_dict
        col_record[col_key] = 1

# %%
# %%time

# main


save_dict = {}
loss_all_val1 = 0
if val_data is not None:
    loss_all_val2 = 0

tuned_parameters = {'n_estimators' : [20], 
                    'max_depth' : [5],
                    'max_features' : ['auto'],
                    'min_samples_split' : [2],
                    'min_samples_leaf' : [5],
                    'bootstrap' : [False]}

#tuned_parameters = {'n_estimators' : [10, 30, 100, 300, 1000, 3000]}
#tuned_parameters = None

param_types = {'n_estimators' : 'uint', 
               'max_depth' : 'uint',
               'max_features' : 'category',
               'min_samples_split' : 'uint',
               'min_samples_leaf' : 'uint',
               'bootstrap' : 'category'}

category_params_dic = {'max_features' : ['auto', 'sqrt'],
                       'bootstrap' : [True, False]}

for i, model_dict_key in enumerate(model_meta_dict):
    data = ori_data.copy()
    model_dict = model_meta_dict[model_dict_key]
    target_col = model_dict['target_col']
    dependent_col_list = model_dict['dependent_col_list']
    if val_data is not None:
        tmp_val_data = val_data.iloc[model_dict['val_data_loc']]
    result = {
        'target_col' : target_col,
        'dependent_col' : dependent_col_list
    }
    print(str(i+1) + '/' + str(len(model_meta_dict)))
    print('key : ', model_dict_key)
    print('loc : ', model_dict['val_data_loc'].values)
    print('tar_col : ', target_col)
    print('dep_col : ', dependent_col_list)

    data['val'] = 0

    if tmp_val_data is not None:
        tmp_val_data['val'] = 1
        data = data.append(tmp_val_data)

    X = data[dependent_col_list + ['val']]
    y = data[[target_col, 'val']]

    X = preprocessing(X)

    if tmp_val_data is not None:
        val_X = X[X['val'] == 1]
        val_y = y[y['val'] == 1]
        X = X[X['val'] == 0]
        y = y[y['val'] == 0]

        val_X = val_X.drop(['val'], axis=1)
        val_y = val_y[target_col].values

    X = X.drop(['val'], axis=1)
    y = y[target_col].values

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=RANDOM_SEED)
    
    if isinstance(y_test[0], str): # clf
        model = CustomClfModel()
    else:
        model = CustomRegModel()
    
    model.train(X_train, y_train, tuned_parameters, val_X, val_y, param_types, category_params_dic)
    print('best parameter : ', model.model.best_params_)
    pred = model.predict(X_test)
    val_eval = model.evaluation(pred, y_test)
    print('val1 : ', val_eval)
    result['val_1'] = val_eval
    official_score_key = [v for v in val_eval if 'Official' in v][0]
    loss_all_val1 += val_eval[official_score_key]

    if tmp_val_data is not None:
        val_pred = model.predict(val_X)
        val_eval = model.evaluation(val_pred, val_y)
        print('val2 : ', val_eval)
        result['val_2'] = val_eval
        official_score_key = [v for v in val_eval if 'Official' in v][0]
        loss_all_val2 += val_eval[official_score_key]

    print()
    save_dict[i] = result
    
    model_meta_dict[model_dict_key]['model'] = model

save_dict['loss_all_val1'] = loss_all_val1
save_dict['loss_all_val2'] = loss_all_val2

now_string = str(datetime.datetime.now())
now_string = now_string.replace(':', '-')
now_string = str(round(loss_all_val2, 4)).zfill(8) + ' ' + now_string
with open('result/' + now_string + '.json', 'w') as f:
    json.dump(save_dict, f)
with open('result/' + now_string + '.p', 'wb') as f:
    pickle.dump(model_dict, f)
# Out:
# 1/48
# key :  사망자수:주야/요일/중상자수/부상신고자수/발생지시도/발생지시군구/사고유형_대분류/사고유형_중분류/법규위반/도로형태_대분류/도로형태/당사자종별_1당_대분류/당사자종별_2당_대분류
# loc :  [0 1]
# tar_col :  사망자수
# dep_col :  ['주야', '요일', '중상자수', '부상신고자수', '발생지시도', '발생지시군구', '사고유형_대분류', '사고유형_중분류', '법규위반', '도로형태_대분류', '도로형태', '당사자종별_1당_대분류', '당사자종별_2당_대분류']
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.9949825916323753
# {'bootstrap': True, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.997749262203663
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.9949825916323753
# {'bootstrap': False, 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.9960492544458563
# {'bootstrap': False, 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.993571929340571
# {'bootstrap': False, 'max_depth': 15, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.9726044771163482
# {'bootstrap': False, 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.9987835499376838
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.9949722164979902
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 20} 1.9953356320290185
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 20} 1.9945519378264258
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 15, 'min_samples_split': 2, 'n_estimators': 20} 1.9953198972692534
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 20} 1.9945617459895848
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 20} 1.9949825916323753
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 20} 1.9949825916323753
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 22} 1.9949825916323753
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 18} 1.9949825916323753
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 60} 1.9949825916323753
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 7} 1.9949825916323753
# {'bootstrap': True, 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.9979976447667949
# {'bootstrap': True, 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.9972742203076086
# {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.993719713496621
# {'bootstrap': True, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 20} 1.9977383551990675
# {'bootstrap': True, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 20} 1.9976272088750853
# {'bootstrap': True, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 15, 'min_samples_split': 2, 'n_estimators': 20} 1.9976070097143959
# {'bootstrap': True, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 20} 1.9973312524558628
# {'bootstrap': True, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 20} 1.997749262203663
# {'bootstrap': True, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 20} 1.997749262203663
# {'bootstrap': True, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 22} 1.9977002080047708
# {'bootstrap': True, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 18} 1.9979480225551765
# {'bootstrap': True, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 60} 1.997631081761867
# {'bootstrap': True, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 7} 1.9970658277364128
# {'bootstrap': True, 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.9975214245072639
# {'bootstrap': False, 'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.998920802968955
# {'bootstrap': False, 'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.9989920428530101
# {'bootstrap': False, 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.9949774612689186
# {'bootstrap': False, 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 20} 1.9987835499376838
# {'bootstrap': False, 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 20} 1.9987835499376838
# {'bootstrap': False, 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 15, 'min_samples_split': 2, 'n_estimators': 20} 1.9987835499376838
# {'bootstrap': False, 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 20} 1.9987835499376838
# {'bootstrap': False, 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 20} 1.9987835499376838
# {'bootstrap': False, 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 20} 1.9987835499376838
# {'bootstrap': False, 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 22} 1.9987835499376838
# {'bootstrap': False, 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 18} 1.9987835499376838
# {'bootstrap': False, 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 60} 1.998783549937684
# {'bootstrap': False, 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 7} 1.998783549937684
# {'bootstrap': True, 'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.997317701287554
# {'bootstrap': False, 'max_depth': 9, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.9976968443419174
# {'bootstrap': False, 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.9950935253426776
# {'bootstrap': False, 'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 20} 1.9982982017951478
# {'bootstrap': False, 'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 20} 1.998920802968955
# {'bootstrap': False, 'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 15, 'min_samples_split': 2, 'n_estimators': 20} 1.9982982017951478
# {'bootstrap': False, 'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 20} 1.998920802968955
# {'bootstrap': False, 'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 20} 1.998920802968955
# {'bootstrap': False, 'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 20} 1.998920802968955
# {'bootstrap': False, 'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 22} 1.9989208029689547
# {'bootstrap': False, 'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 18} 1.998920802968955
# {'bootstrap': True, 'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.9986864881640225
# {'bootstrap': False, 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.9956557306878442
# {'bootstrap': False, 'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 20} 1.9989920428530101
# {'bootstrap': False, 'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 20} 1.9989920428530101
# {'bootstrap': False, 'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 15, 'min_samples_split': 2, 'n_estimators': 20} 1.9989920428530101
# {'bootstrap': False, 'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 20} 1.9989920428530101
# {'bootstrap': False, 'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 20} 1.9989920428530101
# {'bootstrap': False, 'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 20} 1.9989920428530101
# {'bootstrap': False, 'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 22} 1.9989920428530101
# {'bootstrap': False, 'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 18} 1.9989920428530101
# best parameter :  {'bootstrap': False, 'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20}
# val1 :  {'MSE': 0.04992012779552716, 'Official Numerical Score': 4904.400674789872}
# val2 :  {'MSE': 0.0, 'Official Numerical Score': 2.0}
#
# 2/48
# key :  사상자수:주야/요일/중상자수/부상신고자수/발생지시도/발생지시군구/사고유형_대분류/사고유형_중분류/법규위반/도로형태_대분류/도로형태/당사자종별_1당_대분류/당사자종별_2당_대분류
# loc :  [0 1]
# tar_col :  사상자수
# dep_col :  ['주야', '요일', '중상자수', '부상신고자수', '발생지시도', '발생지시군구', '사고유형_대분류', '사고유형_중분류', '법규위반', '도로형태_대분류', '도로형태', '당사자종별_1당_대분류', '당사자종별_2당_대분류']
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.1013237481314513
# {'bootstrap': True, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.11694705846071
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.1013237481314513
# {'bootstrap': False, 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.1416654224804201
# {'bootstrap': False, 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.067502299185011
# {'bootstrap': False, 'max_depth': 15, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.123747424273899
# {'bootstrap': False, 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.0216351999720807
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.5792693440276997
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 20} 1.1013237481314513
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 20} 1.1013237481314513
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 15, 'min_samples_split': 2, 'n_estimators': 20} 1.1013237481314513
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 20} 1.1118239552683096
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 20} 1.1013237481314513
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 22} 1.101323748131451
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 18} 1.1013237481314513
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 60} 1.1013237481314524
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 7} 1.1013237481314508
# {'bootstrap': True, 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.1744171444852678
# {'bootstrap': True, 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.0561255689209066
# {'bootstrap': True, 'max_depth': 15, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.4140086678825725
# {'bootstrap': True, 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.0613400559244957
# {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.6555747025856686
# {'bootstrap': True, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 20} 1.11694705846071
# {'bootstrap': True, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 20} 1.11694705846071
# {'bootstrap': True, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 15, 'min_samples_split': 2, 'n_estimators': 20} 1.1182442312757064
# {'bootstrap': True, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 20} 1.1196909831682729
# {'bootstrap': True, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 20} 1.11694705846071
# {'bootstrap': True, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 20} 1.11694705846071
# {'bootstrap': True, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 22} 1.1130787985875163
# {'bootstrap': True, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 18} 1.107751608898041
# {'bootstrap': True, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 60} 1.1123213963654144
# {'bootstrap': True, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 7} 1.133783134408005
# {'bootstrap': False, 'max_depth': 7, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.232177691133402
# {'bootstrap': False, 'max_depth': 18, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.12585532338042
# {'bootstrap': False, 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.2911359477742126
# {'bootstrap': False, 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 20} 1.1416654224804201
# {'bootstrap': False, 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 20} 1.1416654224804201
# {'bootstrap': False, 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 15, 'min_samples_split': 2, 'n_estimators': 20} 1.1416654224804201
# {'bootstrap': False, 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 20} 1.1429990704818864
# {'bootstrap': False, 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 20} 1.1416654224804201
# {'bootstrap': False, 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 20} 1.1416654224804201
# {'bootstrap': False, 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 22} 1.1416654224804201
# {'bootstrap': False, 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 18} 1.14166542248042
# {'bootstrap': False, 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 60} 1.1416654224804177
# {'bootstrap': False, 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 7} 1.1416654224804192
# {'bootstrap': False, 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.5547566858680237
# {'bootstrap': False, 'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 0.9258745839707989
# {'bootstrap': False, 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.7748178670516825
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 20} 1.5774839665379996
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 20} 1.534117898294423
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 2, 'n_estimators': 20} 1.5728251004822398
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 20} 1.6325752985801973
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 20} 1.5792693440276997
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 20} 1.5792693440276997
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 22} 1.5130929043267383
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 18} 1.5404174726566295
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 60} 1.5111706165287244
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 7} 1.460415961534705
# {'bootstrap': True, 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.5365681719591915
# {'bootstrap': True, 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.6522887746785506
# {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 20} 1.6495082493449167
# {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 20} 1.62063342588725
# {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 2, 'n_estimators': 20} 1.5725758627830946
# {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 20} 1.6346880847451493
# {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 20} 1.6555747025856686
# {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 20} 1.6555747025856686
# {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 22} 1.590771971102497
# {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 18} 1.6253455905648053
# {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 60} 1.514019599582935
# {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 7} 1.5272690018348536
# {'bootstrap': True, 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.8029722862882234
# {'bootstrap': False, 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.5520539159009683
# {'bootstrap': False, 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.7645981973409812
# {'bootstrap': False, 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 20} 1.7748178670516825
# {'bootstrap': False, 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 20} 1.7748178670516825
# {'bootstrap': False, 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 20} 1.7748178670516825
# {'bootstrap': False, 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 20} 1.7748178670516825
# {'bootstrap': False, 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 22} 1.770664125991951
# {'bootstrap': False, 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 18} 1.7665375439845765
# {'bootstrap': False, 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 60} 1.7590764484088894
# {'bootstrap': False, 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 7} 1.6431975781075567
# {'bootstrap': True, 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.712478221903317
# {'bootstrap': True, 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.760946472143476
# {'bootstrap': True, 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 20} 1.8029722862882234
# {'bootstrap': True, 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 20} 1.8026440738281984
# {'bootstrap': True, 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 20} 1.8029722862882234
# {'bootstrap': True, 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 20} 1.8029722862882234
# {'bootstrap': True, 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 22} 1.7740646635625947
# {'bootstrap': True, 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 18} 1.798491312487743
# best parameter :  {'bootstrap': True, 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20}
# val1 :  {'MSE': 2.8570287539936103, 'Official Numerical Score': 3189.7716036607167}
# val2 :  {'MSE': 0.0, 'Official Numerical Score': 2.0}
#
# 3/48
# key :  경상자수:주야/요일/중상자수/부상신고자수/발생지시도/발생지시군구/사고유형_대분류/사고유형_중분류/법규위반/도로형태_대분류/도로형태/당사자종별_1당_대분류/당사자종별_2당_대분류
# loc :  [0 1]
# tar_col :  경상자수
# dep_col :  ['주야', '요일', '중상자수', '부상신고자수', '발생지시도', '발생지시군구', '사고유형_대분류', '사고유형_중분류', '법규위반', '도로형태_대분류', '도로형태', '당사자종별_1당_대분류', '당사자종별_2당_대분류']
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.3295097274037646
# {'bootstrap': True, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.2007104035140128
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.3295097274037646
# {'bootstrap': False, 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.2364470335574536
# {'bootstrap': False, 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.3793388305961405
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.421702379443091
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 20} 1.3295097274037646
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 20} 1.3303140933357998
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 15, 'min_samples_split': 2, 'n_estimators': 20} 1.3295097274037646
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 20} 1.341215675513805
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 20} 1.3295097274037646
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 20} 1.3295097274037646
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 22} 1.3295097274037646
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 18} 1.3295097274037646
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 60} 1.3295097274037648
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 7} 1.3295097274037646
# {'bootstrap': True, 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.3584659066368845
# {'bootstrap': False, 'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.2857550100143604
# {'bootstrap': False, 'max_depth': 12, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 0.9375637291239103
# {'bootstrap': False, 'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.0964915345526312
# {'bootstrap': False, 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.3893293110953215
# {'bootstrap': False, 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 20} 1.3793388305961405
# {'bootstrap': False, 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 20} 1.3793388305961405
# {'bootstrap': False, 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 15, 'min_samples_split': 2, 'n_estimators': 20} 1.3793388305961405
# {'bootstrap': False, 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 20} 1.3435653179026374
# {'bootstrap': False, 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 20} 1.3793388305961405
# {'bootstrap': False, 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 20} 1.3793388305961405
# {'bootstrap': False, 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 22} 1.3793388305961403
# {'bootstrap': False, 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 18} 1.3793388305961405
# {'bootstrap': False, 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 60} 1.3793388305961403
# {'bootstrap': False, 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 7} 1.3793388305961405
# {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.420722334055398
# {'bootstrap': False, 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.486360978158766
# {'bootstrap': False, 'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.4522659403078793
# {'bootstrap': False, 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.2898962008382213
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 20} 1.4211525156152645
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 20} 1.412745049179486
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 2, 'n_estimators': 20} 1.433580769495143
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 20} 1.4444732953805008
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 20} 1.421702379443091
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 20} 1.421702379443091
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 22} 1.442336927210607
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 18} 1.4322206586274004
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 60} 1.4260219705470387
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 7} 1.4025753944549528
# {'bootstrap': True, 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.4474513634478074
# {'bootstrap': False, 'max_depth': 7, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.4518149549515946
# {'bootstrap': False, 'max_depth': 18, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.1560161649722505
# {'bootstrap': False, 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 20} 1.41693925255432
# {'bootstrap': False, 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 20} 1.498081186684505
# {'bootstrap': False, 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 2, 'n_estimators': 20} 1.4362881743100444
# {'bootstrap': False, 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 20} 1.4520845083448022
# {'bootstrap': False, 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 20} 1.486360978158766
# {'bootstrap': False, 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 20} 1.486360978158766
# {'bootstrap': False, 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 22} 1.4927013932811841
# {'bootstrap': False, 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 18} 1.4844770656688573
# {'bootstrap': True, 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 20} 1.4683800600950772
# {'bootstrap': False, 'max_depth': 7, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 20} 1.4854541942045176
# {'bootstrap': False, 'max_depth': 18, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 20} 1.404933088495252
# {'bootstrap': False, 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 20} 1.2898962008382213
# {'bootstrap': False, 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 20} 1.2398311216527291
# {'bootstrap': False, 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 20} 1.4924313154294016
# {'bootstrap': False, 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 3, 'n_estimators': 20} 1.498081186684505
# {'bootstrap': False, 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 22} 1.491472447307013
# {'bootstrap': False, 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 18} 1.4891846503239927
# {'bootstrap': False, 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 60} 1.4602095729538767
# {'bootstrap': False, 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 7} 1.4383023317699872
# best parameter :  {'bootstrap': False, 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 20}
# val1 :  {'MSE': 0.99400958466453671, 'Official Numerical Score': 4444.795357542935}
# val2 :  {'MSE': 0.5, 'Official Numerical Score': 1.3678794411714423}
#
# 4/48
# key :  사상자수:주야/요일/사망자수/경상자수/발생지시도/발생지시군구/사고유형_대분류/사고유형_중분류/법규위반/도로형태_대분류/도로형태/당사자종별_1당_대분류/당사자종별_2당_대분류
# loc :  [2 3]
# tar_col :  사상자수
# dep_col :  ['주야', '요일', '사망자수', '경상자수', '발생지시도', '발생지시군구', '사고유형_대분류', '사고유형_중분류', '법규위반', '도로형태_대분류', '도로형태', '당사자종별_1당_대분류', '당사자종별_2당_대분류']
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.0608505153152126
# {'bootstrap': True, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.0496057971309072
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.0608505153152126
# {'bootstrap': False, 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 0.9854870659634174
# {'bootstrap': False, 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 0.9959562177467175
# {'bootstrap': False, 'max_depth': 15, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 0.9979117511350069
# {'bootstrap': False, 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.6733695509743263
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.7193099737893887
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 20} 1.0608505153152126
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 20} 1.0608505153152126
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 20} 1.0608505153152126
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 22} 1.0608505153152126
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 18} 1.0608505153152126
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 60} 1.0608505153152106
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 7} 1.0608505153152126
# {'bootstrap': True, 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.7020808398369975
# {'bootstrap': False, 'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.9584801897504451
# {'bootstrap': False, 'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 0.864694586933901
# {'bootstrap': False, 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.5644682483745576
# {'bootstrap': False, 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 20} 1.6733695509743263
# {'bootstrap': False, 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 20} 1.6733695509743263
# {'bootstrap': False, 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 20} 1.6733695509743263
# {'bootstrap': False, 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 20} 1.6733695509743263
# {'bootstrap': False, 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 22} 1.6733695509743263
# {'bootstrap': False, 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 18} 1.6733695509743267
# {'bootstrap': False, 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 60} 1.6733695509743258
# {'bootstrap': False, 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 7} 1.6733695509743276
# {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.7289984862285908
# {'bootstrap': False, 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.7834363438542007
# {'bootstrap': False, 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.685762441024338
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 20} 1.7199156777400084
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 20} 1.736723969691588
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 2, 'n_estimators': 20} 1.8109264769841982
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 20} 1.7110722382227614
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 20} 1.7193099737893887
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 20} 1.7193099737893887
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 22} 1.7558851569269183
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 18} 1.7525039310534931
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 60} 1.7802218819457707
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 7} 1.6880329887821959
# {'bootstrap': True, 'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.9383831166163694
# {'bootstrap': False, 'max_depth': 9, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 0.9970155280204522
# {'bootstrap': False, 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.7165806533576262
# {'bootstrap': False, 'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 20} 1.9584801897504451
# {'bootstrap': False, 'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 20} 1.9584801897504451
# {'bootstrap': False, 'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 15, 'min_samples_split': 2, 'n_estimators': 20} 1.9584801897504451
# {'bootstrap': False, 'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 20} 1.9584801897504451
# {'bootstrap': False, 'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 20} 1.9584801897504451
# {'bootstrap': False, 'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 20} 1.9584801897504451
# {'bootstrap': False, 'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 22} 1.9584801897504451
# {'bootstrap': False, 'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 18} 1.9584801897504451
# {'bootstrap': False, 'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 60} 1.9584801897504447
# {'bootstrap': False, 'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 7} 1.9584801897504451
# best parameter :  {'bootstrap': False, 'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20}
# val1 :  {'MSE': 1.2080670926517572, 'Official Numerical Score': 4195.280684245157}
# val2 :  {'MSE': 0.0, 'Official Numerical Score': 2.0}
#
# 5/48
# key :  중상자수:주야/요일/사망자수/경상자수/발생지시도/발생지시군구/사고유형_대분류/사고유형_중분류/법규위반/도로형태_대분류/도로형태/당사자종별_1당_대분류/당사자종별_2당_대분류
# loc :  [2 3]
# tar_col :  중상자수
# dep_col :  ['주야', '요일', '사망자수', '경상자수', '발생지시도', '발생지시군구', '사고유형_대분류', '사고유형_중분류', '법규위반', '도로형태_대분류', '도로형태', '당사자종별_1당_대분류', '당사자종별_2당_대분류']
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.2117333984756518
# {'bootstrap': True, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.1761462963175102
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.2117333984756518
# {'bootstrap': False, 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.2644801842548383
# {'bootstrap': False, 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.699922051277819
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.4584320385902205
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 20} 1.2117333984756518
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 20} 1.2117333984756518
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 15, 'min_samples_split': 2, 'n_estimators': 20} 1.2117333984756518
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 20} 1.2117333984756518
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 20} 1.2117333984756518
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 20} 1.2117333984756518
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 22} 1.2117333984756515
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 18} 1.2117333984756518
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 60} 1.2117333984756518
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 7} 1.211733398475652
# {'bootstrap': True, 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.06410064076329
# {'bootstrap': False, 'max_depth': 7, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.370786534089809
# {'bootstrap': False, 'max_depth': 18, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.89483931681437
# {'bootstrap': False, 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.9209015569582926
# {'bootstrap': False, 'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.3059848309549618
# {'bootstrap': False, 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 20} 0.9668594200948719
# {'bootstrap': False, 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 20} 1.2644801842548383
# {'bootstrap': False, 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 15, 'min_samples_split': 2, 'n_estimators': 20} 1.3294937613234978
# {'bootstrap': False, 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 20} 1.2644801842548383
# {'bootstrap': False, 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 20} 1.2644801842548383
# {'bootstrap': False, 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 20} 1.2644801842548383
# {'bootstrap': False, 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 22} 1.2644801842548383
# {'bootstrap': False, 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 18} 1.2644801842548383
# {'bootstrap': True, 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.309964995484242
# {'bootstrap': False, 'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.6050429344376862
# {'bootstrap': False, 'max_depth': 12, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.8911376871004868
# {'bootstrap': False, 'max_depth': 1, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.8615867583428556
# {'bootstrap': False, 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.4399980720391778
# ...
# {'bootstrap': False, 'max_depth': 18, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 18} 1.8948393168143698
# {'bootstrap': False, 'max_depth': 18, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 60} 1.8948393168143698
# {'bootstrap': False, 'max_depth': 18, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 7} 1.8948393168143698
# {'bootstrap': True, 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.6248124344602357
# {'bootstrap': False, 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.6037469130253774
# {'bootstrap': False, 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 20} 1.9209015569582926
# {'bootstrap': False, 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 20} 1.9209015569582926
# {'bootstrap': False, 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 15, 'min_samples_split': 2, 'n_estimators': 20} 1.9209015569582926
# {'bootstrap': False, 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 20} 1.9209015569582926
# {'bootstrap': False, 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 20} 1.9209015569582926
# {'bootstrap': False, 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 20} 1.9209015569582926
# {'bootstrap': False, 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 22} 1.9209015569582926
# {'bootstrap': False, 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 18} 1.9209015569582926
# {'bootstrap': False, 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 60} 1.9209015569582926
# {'bootstrap': False, 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 7} 1.9209015569582926
# {'bootstrap': True, 'max_depth': 18, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 20} 1.0720381775772074
# {'bootstrap': False, 'max_depth': 20, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 20} 1.9879729106308384
# {'bootstrap': False, 'max_depth': 16, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 20} 1.9879361803595894
# {'bootstrap': False, 'max_depth': 54, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 20} 1.9879729106308384
# {'bootstrap': False, 'max_depth': 18, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 20} 1.3090075904391647
# {'bootstrap': False, 'max_depth': 18, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 20} 2.0
# {'bootstrap': False, 'max_depth': 18, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 3, 'n_estimators': 20} 1.990049833749168
# {'bootstrap': False, 'max_depth': 18, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 6, 'n_estimators': 20} 1.990049833749168
# {'bootstrap': False, 'max_depth': 18, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 22} 1.990049833749168
# {'bootstrap': False, 'max_depth': 18, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 18} 1.990049833749168
# {'bootstrap': False, 'max_depth': 18, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 60} 1.9919327166055711
# {'bootstrap': False, 'max_depth': 18, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 7} 1.9870237031477096
# {'bootstrap': True, 'max_depth': 18, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 20} 1.24228518516034
# {'bootstrap': False, 'max_depth': 20, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 20} 2.0
# {'bootstrap': False, 'max_depth': 16, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 20} 1.9313216718401032
# {'bootstrap': False, 'max_depth': 54, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 20} 2.0
# {'bootstrap': False, 'max_depth': 18, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 20} 1.2689156222022946
# {'bootstrap': False, 'max_depth': 18, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 20} 1.6340515618580673
# {'bootstrap': False, 'max_depth': 18, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 20} 2.0
# {'bootstrap': False, 'max_depth': 18, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 6, 'n_estimators': 20} 2.0
# {'bootstrap': False, 'max_depth': 18, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 22} 2.0
# {'bootstrap': False, 'max_depth': 18, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 18} 2.0
# best parameter :  {'bootstrap': False, 'max_depth': 18, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 20}
# val1 :  {'MSE': 0.90974440894568687, 'Official Numerical Score': 4261.0485092262725}
# val2 :  {'MSE': 0.0, 'Official Numerical Score': 2.0}
#
# 6/48
# key :  부상신고자수:주야/요일/사망자수/경상자수/발생지시도/발생지시군구/사고유형_대분류/사고유형_중분류/법규위반/도로형태_대분류/도로형태/당사자종별_1당_대분류/당사자종별_2당_대분류
# loc :  [2 3]
# tar_col :  부상신고자수
# dep_col :  ['주야', '요일', '사망자수', '경상자수', '발생지시도', '발생지시군구', '사고유형_대분류', '사고유형_중분류', '법규위반', '도로형태_대분류', '도로형태', '당사자종별_1당_대분류', '당사자종별_2당_대분류']
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.9995905904243154
# {'bootstrap': True, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.9982707759823533
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.9995905904243154
# {'bootstrap': False, 'max_depth': 6, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.9973675956634276
# {'bootstrap': False, 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.9995456587071652
# {'bootstrap': False, 'max_depth': 15, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.9998562917860818
# {'bootstrap': False, 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.9987917811461198
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.995083903835425
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 20} 1.9995905904243154
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 20} 1.9995905904243154
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 15, 'min_samples_split': 2, 'n_estimators': 20} 1.9995905904243154
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 20} 1.9995905904243154
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 20} 1.9995905904243154
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 20} 1.9995905904243154
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 22} 1.9995905904243154
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 18} 1.9995905904243154
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 60} 1.9995905904243154
# {'bootstrap': False, 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 7} 1.9995905904243154
# {'bootstrap': True, 'max_depth': 15, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.997620419088145
# {'bootstrap': False, 'max_depth': 16, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.9998665650388445
# {'bootstrap': False, 'max_depth': 14, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.9996749836579937
# {'bootstrap': False, 'max_depth': 45, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.999999148191472
# {'bootstrap': False, 'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.995044607096308
# {'bootstrap': False, 'max_depth': 15, 'max_features': 'auto', 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 20} 1.7786570748574868
# {'bootstrap': False, 'max_depth': 15, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 20} 1.9998562917860818
# {'bootstrap': False, 'max_depth': 15, 'max_features': 'auto', 'min_samples_leaf': 15, 'min_samples_split': 2, 'n_estimators': 20} 1.9998609619816707
# {'bootstrap': False, 'max_depth': 15, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 20} 1.9959576612561993
# {'bootstrap': False, 'max_depth': 15, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 20} 1.9998562917860818
# {'bootstrap': False, 'max_depth': 15, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 20} 1.9998562917860818
# {'bootstrap': False, 'max_depth': 15, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 22} 1.9998562917860818
# {'bootstrap': False, 'max_depth': 15, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 18} 1.9998562917860818
# {'bootstrap': True, 'max_depth': 16, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.9971470439770416
# {'bootstrap': False, 'max_depth': 18, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.9998878075856639
# {'bootstrap': False, 'max_depth': 48, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.999999942436848
# {'bootstrap': False, 'max_depth': 16, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.992360041216788
# {'bootstrap': False, 'max_depth': 16, 'max_features': 'auto', 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 20} 1.7786673481102493
# {'bootstrap': False, 'max_depth': 16, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 20} 1.9998665650388445
# {'bootstrap': False, 'max_depth': 16, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 20} 1.9998665650388445
# {'bootstrap': False, 'max_depth': 16, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 20} 1.9998665650388445
# {'bootstrap': False, 'max_depth': 16, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 22} 1.9998665650388445
# {'bootstrap': False, 'max_depth': 16, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 18} 1.9998665650388445
# {'bootstrap': False, 'max_depth': 16, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 60} 1.9998665650388445
# {'bootstrap': False, 'max_depth': 16, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 7} 1.9998665650388445
# {'bootstrap': True, 'max_depth': 45, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.9961124065316902
# {'bootstrap': False, 'max_depth': 50, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 2.0
# {'bootstrap': False, 'max_depth': 41, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.9999968069546123
# {'bootstrap': False, 'max_depth': 135, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 2.0
# {'bootstrap': False, 'max_depth': 45, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.8897105169431805
# {'bootstrap': False, 'max_depth': 45, 'max_features': 'auto', 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 20} 1.7787999312628768
# {'bootstrap': False, 'max_depth': 45, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 20} 1.999999148191472
# {'bootstrap': False, 'max_depth': 45, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 20} 1.999999148191472
# {'bootstrap': False, 'max_depth': 45, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 22} 1.999999148191472
# {'bootstrap': False, 'max_depth': 45, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 18} 1.999999148191472
# {'bootstrap': False, 'max_depth': 45, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 60} 1.999999148191472
# {'bootstrap': False, 'max_depth': 45, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 7} 1.999999148191472
# {'bootstrap': True, 'max_depth': 48, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.9961335412222914
# {'bootstrap': False, 'max_depth': 53, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 2.0
# {'bootstrap': False, 'max_depth': 44, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.9999986962634675
# {'bootstrap': False, 'max_depth': 144, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 2.0
# {'bootstrap': False, 'max_depth': 48, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 20} 1.9761041773952432
# {'bootstrap': False, 'max_depth': 48, 'max_features': 'auto', 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 20} 1.778800725508253
# {'bootstrap': False, 'max_depth': 48, 'max_features': 'auto', 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 20} 1.999999942436848
# {'bootstrap': False, 'max_depth': 48, 'max_features': 'auto', 'min_samples_leaf': 15, 'min_samples_split': 2, 'n_estimators': 20} 2.0
# {'bootstrap': False, 'max_depth': 48, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 20} 1.999999942436848
# {'bootstrap': False, 'max_depth': 48, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 20} 1.999999942436848
# {'bootstrap': False, 'max_depth': 48, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 20} 1.999999942436848
# {'bootstrap': False, 'max_depth': 48, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 22} 1.999999942436848
# {'bootstrap': False, 'max_depth': 48, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 18} 1.999999942436848

# %%
# check save file
with open('result/' + now_string + '.json', 'r') as f:
    json_ = json.load(f)
    
with open('result/' + now_string + '.p', 'rb') as f:
    model_ = pickle.load(f)

# %%
debug_log = model_meta_dict['사고유형_대분류:주야/요일/사망자수/사상자수/중상자수/경상자수/부상신고자수/발생지시도/발생지시군구/도로형태_대분류/도로형태/당사자종별_1당_대분류/당사자종별_2당_대분류']['val_data_loc']

# %%
model.model.model.get_params()
# Out:
# {'bootstrap': False,
#  'criterion': 'mse',
#  'max_depth': 5,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 20,
#  'n_jobs': 4,
#  'oob_score': False,
#  'random_state': 2018,
#  'verbose': 0,
#  'warm_start': False}

# %%
save_dict
# Out:
# {0: {'dependent_col': ['주야',
#    '요일',
#    '중상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '사망자수',
#   'val_1': {'MSE': 0.070487220447284352,
#    'Official Numerical Score': 4845.52826354399},
#   'val_2': {'MSE': 0.0, 'Official Numerical Score': 2.0}},
#  1: {'dependent_col': ['주야',
#    '요일',
#    '중상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '사상자수',
#   'val_1': {'MSE': 0.93230830670926512,
#    'Official Numerical Score': 4277.32209958561},
#   'val_2': {'MSE': 0.5, 'Official Numerical Score': 1.3678794411714423}},
#  2: {'dependent_col': ['주야',
#    '요일',
#    '중상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '경상자수',
#   'val_1': {'MSE': 0.93130990415335468,
#    'Official Numerical Score': 4363.297532653802},
#   'val_2': {'MSE': 0.5, 'Official Numerical Score': 1.3678794411714423}},
#  3: {'dependent_col': ['주야',
#    '요일',
#    '사망자수',
#    '경상자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '사상자수',
#   'val_1': {'MSE': 0.99500798722044725,
#    'Official Numerical Score': 4214.524881874078},
#   'val_2': {'MSE': 0.0, 'Official Numerical Score': 2.0}},
#  4: {'dependent_col': ['주야',
#    '요일',
#    '사망자수',
#    '경상자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '중상자수',
#   'val_1': {'MSE': 0.83007188498402551,
#    'Official Numerical Score': 4392.8048594333595},
#   'val_2': {'MSE': 0.0, 'Official Numerical Score': 2.0}},
#  5: {'dependent_col': ['주야',
#    '요일',
#    '사망자수',
#    '경상자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '부상신고자수',
#   'val_1': {'MSE': 0.090654952076677314,
#    'Official Numerical Score': 4928.262300780866},
#   'val_2': {'MSE': 0.0, 'Official Numerical Score': 2.0}},
#  6: {'dependent_col': ['주야',
#    '요일',
#    '사망자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '사상자수',
#   'val_1': {'MSE': 2.9347044728434506,
#    'Official Numerical Score': 3670.675072851324},
#   'val_2': {'MSE': 0.33333333333333331,
#    'Official Numerical Score': 2.3678794411714423}},
#  7: {'dependent_col': ['주야',
#    '요일',
#    '사망자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '중상자수',
#   'val_1': {'MSE': 0.98482428115015974,
#    'Official Numerical Score': 4197.397824381355},
#   'val_2': {'MSE': 0.66666666666666663,
#    'Official Numerical Score': 1.7357588823428847}},
#  8: {'dependent_col': ['주야',
#    '요일',
#    '사망자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '경상자수',
#   'val_1': {'MSE': 1.2771565495207668,
#    'Official Numerical Score': 4410.639403784402},
#   'val_2': {'MSE': 0.33333333333333331,
#    'Official Numerical Score': 2.3678794411714423}},
#  9: {'dependent_col': ['주야',
#    '요일',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '사망자수',
#   'val_1': {'MSE': 0.05231629392971246,
#    'Official Numerical Score': 4901.504436523191},
#   'val_2': {'MSE': 0.33333333333333331,
#    'Official Numerical Score': 2.3678794411714423}},
#  10: {'dependent_col': ['주야',
#    '요일',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '사상자수',
#   'val_1': {'MSE': 1.0191693290734825,
#    'Official Numerical Score': 4189.3582292816445},
#   'val_2': {'MSE': 3.3333333333333335,
#    'Official Numerical Score': 1.368002850975529}},
#  11: {'dependent_col': ['주야',
#    '요일',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '중상자수',
#   'val_1': {'MSE': 0.79932108626198084,
#    'Official Numerical Score': 4258.230640527514},
#   'val_2': {'MSE': 3.3333333333333335,
#    'Official Numerical Score': 1.368002850975529}},
#  12: {'dependent_col': ['주야',
#    '요일',
#    '사망자수',
#    '사상자수',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '사고유형_대분류',
#   'val_1': {'ACC': 0.9139376996805112, 'Official Categorical Score': 4577},
#   'val_2': {'ACC': 0.90000000000000002, 'Official Categorical Score': 9}},
#  13: {'dependent_col': ['주야',
#    '요일',
#    '사망자수',
#    '사상자수',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '사고유형_중분류',
#   'val_1': {'ACC': 0.40714856230031948, 'Official Categorical Score': 2039},
#   'val_2': {'ACC': 0.40000000000000002, 'Official Categorical Score': 4}},
#  14: {'dependent_col': ['주야',
#    '요일',
#    '사망자수',
#    '사상자수',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '법규위반',
#   'val_1': {'ACC': 0.72264376996805113, 'Official Categorical Score': 3619},
#   'val_2': {'ACC': 0.90000000000000002, 'Official Categorical Score': 9}},
#  15: {'dependent_col': ['주야',
#    '요일',
#    '사망자수',
#    '사상자수',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '당사자종별_2당_대분류'],
#   'target_col': '도로형태_대분류',
#   'val_1': {'ACC': 0.71765175718849838, 'Official Categorical Score': 3594},
#   'val_2': {'ACC': 1.0, 'Official Categorical Score': 3}},
#  16: {'dependent_col': ['주야',
#    '요일',
#    '사망자수',
#    '사상자수',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '당사자종별_2당_대분류'],
#   'target_col': '도로형태',
#   'val_1': {'ACC': 0.64416932907348246, 'Official Categorical Score': 3226},
#   'val_2': {'ACC': 1.0, 'Official Categorical Score': 3}},
#  17: {'dependent_col': ['주야',
#    '요일',
#    '사망자수',
#    '사상자수',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '당사자종별_2당_대분류'],
#   'target_col': '당사자종별_1당_대분류',
#   'val_1': {'ACC': 0.50059904153354629, 'Official Categorical Score': 2507},
#   'val_2': {'ACC': 0.0, 'Official Categorical Score': 0}},
#  18: {'dependent_col': ['주야',
#    '요일',
#    '사망자수',
#    '사상자수',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '당사자종별_1당_대분류'],
#   'target_col': '도로형태_대분류',
#   'val_1': {'ACC': 0.72464057507987223, 'Official Categorical Score': 3629},
#   'val_2': {'ACC': 0.33333333333333331, 'Official Categorical Score': 1}},
#  19: {'dependent_col': ['주야',
#    '요일',
#    '사망자수',
#    '사상자수',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '당사자종별_1당_대분류'],
#   'target_col': '도로형태',
#   'val_1': {'ACC': 0.64137380191693294, 'Official Categorical Score': 3212},
#   'val_2': {'ACC': 0.33333333333333331, 'Official Categorical Score': 1}},
#  20: {'dependent_col': ['주야',
#    '요일',
#    '사망자수',
#    '사상자수',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '당사자종별_1당_대분류'],
#   'target_col': '당사자종별_2당_대분류',
#   'val_1': {'ACC': 0.76557507987220452, 'Official Categorical Score': 3834},
#   'val_2': {'ACC': 1.0, 'Official Categorical Score': 3}},
#  21: {'dependent_col': ['주야',
#    '요일',
#    '사망자수',
#    '사상자수',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반'],
#   'target_col': '도로형태_대분류',
#   'val_1': {'ACC': 0.72204472843450485, 'Official Categorical Score': 3616},
#   'val_2': {'ACC': 0.75, 'Official Categorical Score': 3}},
#  22: {'dependent_col': ['주야',
#    '요일',
#    '사망자수',
#    '사상자수',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반'],
#   'target_col': '도로형태',
#   'val_1': {'ACC': 0.65075878594249204, 'Official Categorical Score': 3259},
#   'val_2': {'ACC': 0.75, 'Official Categorical Score': 3}},
#  23: {'dependent_col': ['주야',
#    '요일',
#    '사망자수',
#    '사상자수',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반'],
#   'target_col': '당사자종별_1당_대분류',
#   'val_1': {'ACC': 0.50059904153354629, 'Official Categorical Score': 2507},
#   'val_2': {'ACC': 0.5, 'Official Categorical Score': 2}},
#  24: {'dependent_col': ['주야',
#    '요일',
#    '사망자수',
#    '사상자수',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반'],
#   'target_col': '당사자종별_2당_대분류',
#   'val_1': {'ACC': 0.70467252396166136, 'Official Categorical Score': 3529},
#   'val_2': {'ACC': 0.5, 'Official Categorical Score': 2}},
#  25: {'dependent_col': ['주야',
#    '요일',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '사망자수',
#   'val_1': {'MSE': 0.052116613418530348,
#    'Official Numerical Score': 4900.589759207815},
#   'val_2': {'MSE': 0.5, 'Official Numerical Score': 1.3678794411714423}},
#  26: {'dependent_col': ['주야',
#    '요일',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '사상자수',
#   'val_1': {'MSE': 0.1204073482428115,
#    'Official Numerical Score': 4845.213438323434},
#   'val_2': {'MSE': 0.5, 'Official Numerical Score': 1.3678794411714423}},
#  27: {'dependent_col': ['주야',
#    '요일',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '발생지시군구',
#   'val_1': {'ACC': 0.13757987220447285, 'Official Categorical Score': 689},
#   'val_2': {'ACC': 0.0, 'Official Categorical Score': 0}},
#  28: {'dependent_col': ['주야',
#    '요일',
#    '사망자수',
#    '사상자수',
#    '부상신고자수',
#    '발생지시도',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '중상자수',
#   'val_1': {'MSE': 0.39157348242811502,
#    'Official Numerical Score': 4547.2236222730835},
#   'val_2': {'MSE': 1.6666666666666667,
#    'Official Numerical Score': 1.3861950800601766}},
#  29: {'dependent_col': ['주야',
#    '요일',
#    '사망자수',
#    '사상자수',
#    '부상신고자수',
#    '발생지시도',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '경상자수',
#   'val_1': {'MSE': 0.33965654952076679,
#    'Official Numerical Score': 4547.011119506372},
#   'val_2': {'MSE': 0.66666666666666663,
#    'Official Numerical Score': 1.7357588823428847}},
#  30: {'dependent_col': ['주야',
#    '요일',
#    '사망자수',
#    '사상자수',
#    '부상신고자수',
#    '발생지시도',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '발생지시군구',
#   'val_1': {'ACC': 0.15355431309904152, 'Official Categorical Score': 769},
#   'val_2': {'ACC': 0.33333333333333331, 'Official Categorical Score': 1}},
#  31: {'dependent_col': ['주야',
#    '요일',
#    '사망자수',
#    '사상자수',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '발생지시도',
#   'val_1': {'ACC': 0.19848242811501599, 'Official Categorical Score': 994},
#   'val_2': {'ACC': 0.0, 'Official Categorical Score': 0}},
#  32: {'dependent_col': ['주야',
#    '요일',
#    '사망자수',
#    '사상자수',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '발생지시군구',
#   'val_1': {'ACC': 0.022164536741214057, 'Official Categorical Score': 111},
#   'val_2': {'ACC': 0.0, 'Official Categorical Score': 0}},
#  33: {'dependent_col': ['주야',
#    '사망자수',
#    '사상자수',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '법규위반',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '요일',
#   'val_1': {'ACC': 0.15095846645367411, 'Official Categorical Score': 756},
#   'val_2': {'ACC': 0.5, 'Official Categorical Score': 1}},
#  34: {'dependent_col': ['주야',
#    '사망자수',
#    '사상자수',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '법규위반',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '사고유형_대분류',
#   'val_1': {'ACC': 0.99900159744408945, 'Official Categorical Score': 5003},
#   'val_2': {'ACC': 1.0, 'Official Categorical Score': 2}},
#  35: {'dependent_col': ['주야',
#    '사망자수',
#    '사상자수',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '법규위반',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '사고유형_중분류',
#   'val_1': {'ACC': 0.50359424920127793, 'Official Categorical Score': 2522},
#   'val_2': {'ACC': 0.0, 'Official Categorical Score': 0}},
#  36: {'dependent_col': ['주야',
#    '사망자수',
#    '사상자수',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '요일',
#   'val_1': {'ACC': 0.16174121405750799, 'Official Categorical Score': 810},
#   'val_2': {'ACC': 0.0, 'Official Categorical Score': 0}},
#  37: {'dependent_col': ['주야',
#    '사망자수',
#    '사상자수',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '사고유형_중분류',
#   'val_1': {'ACC': 0.45946485623003197, 'Official Categorical Score': 2301},
#   'val_2': {'ACC': 0.33333333333333331, 'Official Categorical Score': 1}},
#  38: {'dependent_col': ['주야',
#    '사망자수',
#    '사상자수',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '법규위반',
#   'val_1': {'ACC': 0.74960063897763574, 'Official Categorical Score': 3754},
#   'val_2': {'ACC': 1.0, 'Official Categorical Score': 3}},
#  39: {'dependent_col': ['주야',
#    '사망자수',
#    '사상자수',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '도로형태',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '도로형태_대분류',
#   'val_1': {'ACC': 0.96046325878594252, 'Official Categorical Score': 4810},
#   'val_2': {'ACC': 1.0, 'Official Categorical Score': 3}},
#  40: {'dependent_col': ['요일',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_2당_대분류'],
#   'target_col': '주야',
#   'val_1': {'ACC': 0.59085463258785942, 'Official Categorical Score': 2959},
#   'val_2': {'ACC': 1.0, 'Official Categorical Score': 2}},
#  41: {'dependent_col': ['요일',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_2당_대분류'],
#   'target_col': '사망자수',
#   'val_1': {'MSE': 0.052116613418530348,
#    'Official Numerical Score': 4900.589759207815},
#   'val_2': {'MSE': 0.5, 'Official Numerical Score': 1.3678794411714423}},
#  42: {'dependent_col': ['요일',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_2당_대분류'],
#   'target_col': '사상자수',
#   'val_1': {'MSE': 0.15654952076677317,
#    'Official Numerical Score': 4775.828719404808},
#   'val_2': {'MSE': 0.5, 'Official Numerical Score': 1.3678794411714423}},
#  43: {'dependent_col': ['요일',
#    '중상자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '도로형태_대분류',
#    '도로형태',
#    '당사자종별_2당_대분류'],
#   'target_col': '당사자종별_1당_대분류',
#   'val_1': {'ACC': 0.50059904153354629, 'Official Categorical Score': 2507},
#   'val_2': {'ACC': 0.0, 'Official Categorical Score': 0}},
#  44: {'dependent_col': ['요일',
#    '사망자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '도로형태_대분류',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '주야',
#   'val_1': {'ACC': 0.60702875399361023, 'Official Categorical Score': 3040},
#   'val_2': {'ACC': 0.66666666666666663, 'Official Categorical Score': 2}},
#  45: {'dependent_col': ['요일',
#    '사망자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '도로형태_대분류',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '사상자수',
#   'val_1': {'MSE': 1.0748801916932906,
#    'Official Numerical Score': 4215.87419896929},
#   'val_2': {'MSE': 0.33333333333333331,
#    'Official Numerical Score': 2.3678794411714423}},
#  46: {'dependent_col': ['요일',
#    '사망자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '도로형태_대분류',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '중상자수',
#   'val_1': {'MSE': 0.86821086261980829,
#    'Official Numerical Score': 4296.920138905199},
#   'val_2': {'MSE': 0.0, 'Official Numerical Score': 3.0}},
#  47: {'dependent_col': ['요일',
#    '사망자수',
#    '경상자수',
#    '부상신고자수',
#    '발생지시도',
#    '발생지시군구',
#    '사고유형_대분류',
#    '사고유형_중분류',
#    '법규위반',
#    '도로형태_대분류',
#    '당사자종별_1당_대분류',
#    '당사자종별_2당_대분류'],
#   'target_col': '도로형태',
#   'val_1': {'ACC': 0.82348242811501593, 'Official Categorical Score': 4124},
#   'val_2': {'ACC': 0.66666666666666663, 'Official Categorical Score': 2}},
#  'loss_all_val1': 167975.79630101897,
#  'loss_all_val2': 96.27251295841141}
